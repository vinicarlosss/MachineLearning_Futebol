# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
matches = pd.read_csv("./data/matches2024.csv", encoding='utf-8')

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0.0   0.0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0.0   1.0
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0.0   0.0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0.0   0.0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0.0   0.0
#
#   season       team
# 0   2024  Liverpool
# 1   2024  Liverpool
# 2   2024  Liverpool
# 3   2024  Liverpool
# 4   2024  Liverpool
#
# [5 rows x 27 columns]

# %%
print(matches.shape)
# Out:
# (760, 27)

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   38
# Aston Villa                 38
# Burnley                     38
# Luton Town                  38
# Everton                     38
# Brentford                   38
# Nottingham Forest           38
# Crystal Palace              38
# Fulham                      38
# Bournemouth                 38
# Wolverhampton Wanderers     38
# Chelsea                     38
# Newcastle United            38
# Manchester United           38
# Brighton and Hove Albion    38
# West Ham United             38
# Tottenham Hotspur           38
# Arsenal                     38
# Manchester City             38
# Sheffield United            38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# 5   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      W  3.0
# 6   2023-09-30  17:30  Premier League   Matchweek 7  Sat  Away      L  1.0
# 7   2023-10-08  14:00  Premier League   Matchweek 8  Sun  Away      D  2.0
# 8   2023-10-21  12:30  Premier League   Matchweek 9  Sat  Home      W  2.0
# 9   2023-10-29  14:00  Premier League  Matchweek 10  Sun  Home      W  3.0
# 10  2023-11-05  16:30  Premier League  Matchweek 11  Sun  Away      D  1.0
# 11  2023-11-12  14:00  Premier League  Matchweek 12  Sun  Home      W  3.0
# 12  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Away      D  1.0
# 13  2023-12-03  14:00  Premier League  Matchweek 14  Sun  Home      W  4.0
# 14  2023-12-06  19:30  Premier League  Matchweek 15  Wed  Away      W  2.0
# 15  2023-12-09  12:30  Premier League  Matchweek 16  Sat  Away      W  2.0
# 16  2023-12-17  16:30  Premier League  Matchweek 17  Sun  Home      D  0.0
# 17  2023-12-23  17:30  Premier League  Matchweek 18  Sat  Home      D  1.0
# 18  2023-12-26  17:30  Premier League  Matchweek 19  Tue  Away      W  2.0
# 19  2024-01-01  20:00  Premier League  Matchweek 20  Mon  Home      W  4.0
# 20  2024-01-21  16:30  Premier League  Matchweek 21  Sun  Away    NaN  NaN
# 21  2024-01-31  20:15  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 22  2024-02-04  16:30  Premier League  Matchweek 23  Sun  Away    NaN  NaN
# 23  2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 24  2024-02-17  12:30  Premier League  Matchweek 25  Sat  Away    NaN  NaN
# 25  2024-02-24  15:00  Premier League  Matchweek 26  Sat  Home    NaN  NaN
# 26  2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away    NaN  NaN
# 27  2024-03-09    NaN  Premier League  Matchweek 28  Sat  Home    NaN  NaN
# 28  2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 29  2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 30  2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 31  2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 32  2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 33  2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 34  2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 35  2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 36  2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 37  2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 0   1.0          Chelsea  ...  Match Report    NaN  13.0   1.0  17.8  0.0
# 1   1.0      Bournemouth  ...  Match Report    NaN  25.0   9.0  16.8  1.0
# 2   1.0    Newcastle Utd  ...  Match Report    NaN   9.0   4.0  17.2  1.0
# 3   0.0      Aston Villa  ...  Match Report    NaN  17.0   4.0  14.7  0.0
# 4   1.0           Wolves  ...  Match Report    NaN  16.0   5.0  15.8  0.0
# 5   1.0         West Ham  ...  Match Report    NaN  21.0   6.0  19.3  2.0
# 6   2.0        Tottenham  ...  Match Report    NaN  12.0   4.0  14.9  0.0
# 7   2.0         Brighton  ...  Match Report    NaN  13.0   3.0  18.8  0.0
# 8   0.0          Everton  ...  Match Report    NaN  25.0   5.0  22.4  1.0
# 9   0.0  Nott'ham Forest  ...  Match Report    NaN  21.0   8.0  19.5  2.0
# 10  1.0       Luton Town  ...  Match Report    NaN  24.0   6.0  17.5  0.0
# 11  0.0        Brentford  ...  Match Report    NaN  17.0  10.0  19.0  0.0
# 12  1.0  Manchester City  ...  Match Report    NaN   8.0   3.0  15.9  0.0
# 13  3.0           Fulham  ...  Match Report    NaN  26.0  12.0  18.9  1.0
# 14  0.0    Sheffield Utd  ...  Match Report    NaN  15.0   8.0  16.4  0.0
# 15  1.0   Crystal Palace  ...  Match Report    NaN  14.0   2.0  17.4  0.0
# 16  0.0   Manchester Utd  ...  Match Report    NaN  34.0   8.0  17.7  0.0
# 17  1.0          Arsenal  ...  Match Report    NaN  13.0   3.0  20.1  1.0
# 18  0.0          Burnley  ...  Match Report    NaN  19.0  10.0  17.4  0.0
# 19  2.0    Newcastle Utd  ...  Match Report    NaN  32.0  12.0  16.2  0.0
# 20  NaN      Bournemouth  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 21  NaN          Chelsea  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 22  NaN          Arsenal  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 23  NaN          Burnley  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 24  NaN        Brentford  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 25  NaN       Luton Town  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 26  NaN  Nott'ham Forest  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 27  NaN  Manchester City  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 28  NaN          Everton  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 29  NaN         Brighton  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 30  NaN    Sheffield Utd  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 31  NaN   Manchester Utd  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 32  NaN   Crystal Palace  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 33  NaN           Fulham  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 34  NaN         West Ham  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 35  NaN        Tottenham  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 36  NaN      Aston Villa  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
# 37  NaN           Wolves  ...  Head-to-Head    NaN   NaN   NaN   NaN  NaN
#
#      pk pkatt season       team
# 0   0.0   0.0   2024  Liverpool
# 1   0.0   1.0   2024  Liverpool
# 2   0.0   0.0   2024  Liverpool
# 3   0.0   0.0   2024  Liverpool
# 4   0.0   0.0   2024  Liverpool
# 5   1.0   1.0   2024  Liverpool
# 6   0.0   0.0   2024  Liverpool
# 7   1.0   1.0   2024  Liverpool
# 8   1.0   1.0   2024  Liverpool
# 9   0.0   0.0   2024  Liverpool
# 10  0.0   0.0   2024  Liverpool
# 11  0.0   0.0   2024  Liverpool
# 12  0.0   0.0   2024  Liverpool
# 13  0.0   0.0   2024  Liverpool
# 14  0.0   0.0   2024  Liverpool
# 15  0.0   0.0   2024  Liverpool
# 16  0.0   0.0   2024  Liverpool
# 17  0.0   0.0   2024  Liverpool
# 18  0.0   0.0   2024  Liverpool
# 19  1.0   2.0   2024  Liverpool
# 20  NaN   NaN   2024  Liverpool
# 21  NaN   NaN   2024  Liverpool
# 22  NaN   NaN   2024  Liverpool
# 23  NaN   NaN   2024  Liverpool
# 24  NaN   NaN   2024  Liverpool
# 25  NaN   NaN   2024  Liverpool
# 26  NaN   NaN   2024  Liverpool
# 27  NaN   NaN   2024  Liverpool
# 28  NaN   NaN   2024  Liverpool
# 29  NaN   NaN   2024  Liverpool
# 30  NaN   NaN   2024  Liverpool
# 31  NaN   NaN   2024  Liverpool
# 32  NaN   NaN   2024  Liverpool
# 33  NaN   NaN   2024  Liverpool
# 34  NaN   NaN   2024  Liverpool
# 35  NaN   NaN   2024  Liverpool
# 36  NaN   NaN   2024  Liverpool
# 37  NaN   NaN   2024  Liverpool
#
# [38 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     20
# Matchweek 29    20
# Matchweek 22    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 28    20
# Matchweek 30    20
# Matchweek 2     20
# Matchweek 31    20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 21    20
# Matchweek 20    20
# Matchweek 19    20
# Matchweek 18    20
# Matchweek 3     20
# Matchweek 4     20
# Matchweek 5     20
# Matchweek 6     20
# Matchweek 7     20
# Matchweek 8     20
# Matchweek 9     20
# Matchweek 10    20
# Matchweek 11    20
# Matchweek 12    20
# Matchweek 13    20
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches['hour'] = matches['time'].fillna('N/A').str.replace(':.+', '', regex=True)
matches['hour'] = pd.to_numeric(matches['hour'], errors='coerce')
matches['hour'] = matches['hour'].fillna(matches['time'])
matches['hour'] = matches['hour'].replace({pd.NA: None}).astype('Int64')
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 755 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Home    NaN  NaN
# 756 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 757 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 758 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 759 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...   fk   pk  pkatt  season              team  \
# 0    1.0          Chelsea  ...  0.0  0.0    0.0    2024         Liverpool
# 1    1.0      Bournemouth  ...  1.0  0.0    1.0    2024         Liverpool
# 2    1.0    Newcastle Utd  ...  1.0  0.0    0.0    2024         Liverpool
# 3    0.0      Aston Villa  ...  0.0  0.0    0.0    2024         Liverpool
# 4    1.0           Wolves  ...  0.0  0.0    0.0    2024         Liverpool
# ..   ...              ...  ...  ...  ...    ...     ...               ...
# 755  NaN          Burnley  ...  NaN  NaN    NaN    2024  Sheffield United
# 756  NaN    Newcastle Utd  ...  NaN  NaN    NaN    2024  Sheffield United
# 757  NaN  Nott'ham Forest  ...  NaN  NaN    NaN    2024  Sheffield United
# 758  NaN          Everton  ...  NaN  NaN    NaN    2024  Sheffield United
# 759  NaN        Tottenham  ...  NaN  NaN    NaN    2024  Sheffield United
#
#     target venue_code opp_code  hour  day_code
# 0        0          0        6    16         6
# 1        1          1        2    15         5
# 2        1          0       14    16         6
# 3        1          1        1    14         6
# 4        1          0       19    12         5
# ..     ...        ...      ...   ...       ...
# 755      0          1        5  <NA>         5
# 756      0          0       14  <NA>         5
# 757      0          1       15  <NA>         5
# 758      0          0        8  <NA>         5
# 759      0          1       17  <NA>         6
#
# [760 rows x 32 columns]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2023-12-10']
test = matches[(matches["date"] >= '2023-12-10') & (matches["date"] <= '2024-01-02')]
test.dropna(subset=['hour'], inplace=True)
test.dropna(subset=['result'], inplace=True)
predictors =["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_11764\3461054510.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.dropna(subset=['hour'], inplace=True)
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_11764\3461054510.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.dropna(subset=['result'], inplace=True)
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.5833333333333334

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           35  13
# 1           22  14

# %%
precision_score(test["target"], preds, average='micro')
# Out:
# 0.5833333333333334

# %%
groupsed_matches = matches.groupby("team")

# %%
group = groupsed_matches.get_group("Manchester City")
group
# Out:
#           date   time            comp         round  day venue result   gf  \
# 76  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 77  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 78  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 79  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 80  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 81  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 82  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 83  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 84  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 85  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 86  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 87  2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 88  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 89  2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 90  2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 91  2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 92  2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 93  2023-12-23    NaN  Premier League  Matchweek 18  Sat  Home    NaN  NaN
# 94  2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 95  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 96  2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away    NaN  NaN
# 97  2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 98  2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away    NaN  NaN
# 99  2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 100 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home    NaN  NaN
# 101 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away    NaN  NaN
# 102 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Home    NaN  NaN
# 103 2024-03-09    NaN  Premier League  Matchweek 28  Sat  Away    NaN  NaN
# 104 2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 105 2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 106 2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 107 2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 108 2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 109 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 110 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 111 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 112 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 113 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...   fk   pk  pkatt  season             team  \
# 76   0.0          Burnley  ...  0.0  0.0    0.0    2024  Manchester City
# 77   0.0    Newcastle Utd  ...  0.0  0.0    0.0    2024  Manchester City
# 78   1.0    Sheffield Utd  ...  2.0  0.0    1.0    2024  Manchester City
# 79   1.0           Fulham  ...  0.0  1.0    1.0    2024  Manchester City
# 80   1.0         West Ham  ...  1.0  0.0    0.0    2024  Manchester City
# 81   0.0  Nott'ham Forest  ...  2.0  0.0    0.0    2024  Manchester City
# 82   2.0           Wolves  ...  1.0  0.0    0.0    2024  Manchester City
# 83   1.0          Arsenal  ...  0.0  0.0    0.0    2024  Manchester City
# 84   1.0         Brighton  ...  1.0  0.0    0.0    2024  Manchester City
# 85   0.0   Manchester Utd  ...  2.0  1.0    1.0    2024  Manchester City
# 86   1.0      Bournemouth  ...  0.0  0.0    0.0    2024  Manchester City
# 87   4.0          Chelsea  ...  1.0  1.0    1.0    2024  Manchester City
# 88   1.0        Liverpool  ...  1.0  0.0    0.0    2024  Manchester City
# 89   3.0        Tottenham  ...  0.0  0.0    0.0    2024  Manchester City
# 90   1.0      Aston Villa  ...  0.0  0.0    0.0    2024  Manchester City
# 91   1.0       Luton Town  ...  1.0  0.0    0.0    2024  Manchester City
# 92   2.0   Crystal Palace  ...  0.0  0.0    0.0    2024  Manchester City
# 93   NaN        Brentford  ...  NaN  NaN    NaN    2024  Manchester City
# 94   1.0          Everton  ...  1.0  1.0    1.0    2024  Manchester City
# 95   0.0    Sheffield Utd  ...  0.0  0.0    0.0    2024  Manchester City
# 96   NaN    Newcastle Utd  ...  NaN  NaN    NaN    2024  Manchester City
# 97   NaN          Burnley  ...  NaN  NaN    NaN    2024  Manchester City
# 98   NaN        Brentford  ...  NaN  NaN    NaN    2024  Manchester City
# 99   NaN          Everton  ...  NaN  NaN    NaN    2024  Manchester City
# 100  NaN          Chelsea  ...  NaN  NaN    NaN    2024  Manchester City
# 101  NaN      Bournemouth  ...  NaN  NaN    NaN    2024  Manchester City
# 102  NaN   Manchester Utd  ...  NaN  NaN    NaN    2024  Manchester City
# 103  NaN        Liverpool  ...  NaN  NaN    NaN    2024  Manchester City
# 104  NaN         Brighton  ...  NaN  NaN    NaN    2024  Manchester City
# 105  NaN          Arsenal  ...  NaN  NaN    NaN    2024  Manchester City
# 106  NaN      Aston Villa  ...  NaN  NaN    NaN    2024  Manchester City
# 107  NaN   Crystal Palace  ...  NaN  NaN    NaN    2024  Manchester City
# 108  NaN       Luton Town  ...  NaN  NaN    NaN    2024  Manchester City
# 109  NaN        Tottenham  ...  NaN  NaN    NaN    2024  Manchester City
# 110  NaN  Nott'ham Forest  ...  NaN  NaN    NaN    2024  Manchester City
# 111  NaN           Wolves  ...  NaN  NaN    NaN    2024  Manchester City
# 112  NaN           Fulham  ...  NaN  NaN    NaN    2024  Manchester City
# 113  NaN         West Ham  ...  NaN  NaN    NaN    2024  Manchester City
#
#     target venue_code opp_code  hour  day_code
# 76       1          0        5    20         4
# 77       1          1       14    20         5
# 78       1          0       16    14         6
# 79       1          1        9    15         5
# 80       1          0       18    15         5
# 81       1          1       15    15         5
# 82       0          0       19    15         5
# 83       0          0        0    16         6
# 84       1          1        4    15         5
# 85       1          0       13    15         6
# 86       1          1        2    15         5
# 87       0          0        6    16         6
# 88       0          1       10    12         5
# 89       0          1       17    16         6
# 90       0          0        1    20         2
# 91       1          0       11    14         6
# 92       0          1        7    15         5
# 93       0          1        3  <NA>         5
# 94       1          0        8    20         2
# 95       1          1       16    15         5
# 96       0          0       14    17         5
# 97       0          1        5    19         2
# 98       0          0        3    20         0
# 99       0          1        8    12         5
# 100      0          1        6    17         5
# 101      0          0        2    17         5
# 102      0          1       13    15         5
# 103      0          0       10  <NA>         5
# 104      0          0        4  <NA>         5
# 105      0          1        0  <NA>         5
# 106      0          1        1  <NA>         2
# 107      0          0        7  <NA>         5
# 108      0          1       11  <NA>         5
# 109      0          0       17  <NA>         5
# 110      0          0       15  <NA>         5
# 111      0          1       19  <NA>         5
# 112      0          0        9  <NA>         5
# 113      0          1       18  <NA>         6
#
# [38 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
    group[new_cols] = rolling_stats
    nan_index = group[group[new_cols].isna()].index
    for idx in nan_index:
        for col in new_cols:  # Ignora a coluna 'Rodada'
            group.at[idx, f'{col}'] = group.loc[idx - 3 + 1:idx, col].mean()
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
#           date   time            comp         round  day venue result   gf  \
# 76  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 77  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 78  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 79  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 80  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 81  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 82  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 83  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 84  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 85  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 86  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 87  2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 88  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 89  2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 90  2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 91  2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 92  2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 93  2023-12-23    NaN  Premier League  Matchweek 18  Sat  Home    NaN  NaN
# 94  2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 95  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 96  2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away    NaN  NaN
# 97  2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 98  2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away    NaN  NaN
# 99  2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 100 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home    NaN  NaN
# 101 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away    NaN  NaN
# 102 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Home    NaN  NaN
# 103 2024-03-09    NaN  Premier League  Matchweek 28  Sat  Away    NaN  NaN
# 104 2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 105 2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 106 2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 107 2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 108 2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 109 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 110 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 111 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 112 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 113 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...  hour  day_code  gf_rolling  ga_rolling  \
# 76   0.0          Burnley  ...    20         4    2.000000    0.333333
# 77   0.0    Newcastle Utd  ...    20         5    2.000000    0.333333
# 78   1.0    Sheffield Utd  ...    14         6    2.000000    0.333333
# 79   1.0           Fulham  ...    15         5    2.000000    0.333333
# 80   1.0         West Ham  ...    15         5    2.000000    0.333333
# 81   0.0  Nott'ham Forest  ...    15         5    2.222222    0.444444
# 82   2.0           Wolves  ...    15         5    2.518519    0.592593
# 83   1.0          Arsenal  ...    16         6    2.691358    0.567901
# 84   1.0         Brighton  ...    15         5    2.403292    0.720165
# 85   0.0   Manchester Utd  ...    15         6    2.031550    0.762689
# 86   1.0      Bournemouth  ...    15         5    1.811614    0.938729
# 87   4.0          Chelsea  ...    16         6    1.836610    0.789361
# 88   1.0        Liverpool  ...    12         5    2.438297    0.798252
# 89   3.0        Tottenham  ...    16         6    2.869414    1.084760
# 90   1.0      Aston Villa  ...    20         2    2.991459    1.294337
# 91   1.0       Luton Town  ...    14         6    2.842513    1.681921
# 92   2.0   Crystal Palace  ...    15         5    2.389102    1.547642
# 93   NaN        Brentford  ...  <NA>         5    2.299427    1.632077
# 94   1.0          Everton  ...    20         2    2.007287    1.504351
# 95   0.0    Sheffield Utd  ...    15         5    2.153357    1.568214
# 96   NaN    Newcastle Utd  ...    17         5    2.080322    1.536282
# 97   NaN          Burnley  ...    19         2    2.116840    1.552248
# 98   NaN        Brentford  ...    20         0    2.098581    1.544265
# 99   NaN          Everton  ...    12         5    2.107710    1.548256
# 100  NaN          Chelsea  ...    17         5    2.103146    1.546261
# 101  NaN      Bournemouth  ...    17         5    2.105428    1.547259
# 102  NaN   Manchester Utd  ...    15         5    2.104287    1.546760
# 103  NaN        Liverpool  ...  <NA>         5    2.104858    1.547009
# 104  NaN         Brighton  ...  <NA>         5    2.104572    1.546884
# 105  NaN          Arsenal  ...  <NA>         5    2.104715    1.546947
# 106  NaN      Aston Villa  ...  <NA>         2    2.104644    1.546916
# 107  NaN   Crystal Palace  ...  <NA>         5    2.104679    1.546931
# 108  NaN       Luton Town  ...  <NA>         5    2.104661    1.546923
# 109  NaN        Tottenham  ...  <NA>         5    2.104670    1.546927
# 110  NaN  Nott'ham Forest  ...  <NA>         5    2.104666    1.546925
# 111  NaN           Wolves  ...  <NA>         5    2.104668    1.546926
# 112  NaN           Fulham  ...  <NA>         5    2.104667    1.546926
# 113  NaN         West Ham  ...  <NA>         6    2.104668    1.546926
#
#     sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 76   20.000000    7.000000    16.366667   0.666667   0.000000       0.333333
# 77   20.000000    7.000000    16.366667   0.666667   0.000000       0.333333
# 78   20.000000    7.000000    16.366667   0.666667   0.000000       0.333333
# 79   20.000000    7.000000    16.366667   0.666667   0.000000       0.333333
# 80   20.000000    7.000000    16.366667   0.666667   0.000000       0.333333
# 81   18.777778    6.555556    16.466667   0.666667   0.111111       0.444444
# 82   20.037037    7.407407    16.333333   0.777778   0.148148       0.481481
# 83   17.604938    6.987654    16.311111   0.814815   0.197531       0.419753
# 84   19.102881    7.576132    16.759259   0.975309   0.115226       0.300412
# 85   16.013717    6.187929    16.734568   0.930041   0.104252       0.240055
# 86   15.816644    6.032465    17.053498   0.857339   0.073160       0.180155
# 87   14.387898    5.629020    16.918244   0.929127   0.170248       0.251181
# 88   15.734847    6.331606    17.146136   0.928822   0.192247       0.254890
# 89   16.152026    6.875764    16.932571   0.952649   0.343054       0.390913
# 90   16.295625    6.846901    16.837347   0.849379   0.289545       0.326379
# 91   16.038106    6.574222    16.401084   0.822898   0.321977       0.350208
# 92   14.666799    5.695930    15.201699   0.668537   0.203841       0.225529
# 93   14.346079    5.423384    14.923150   0.608256   0.175273       0.191912
# 94   14.004293    5.595327    14.963839   0.536709   0.126371       0.139147
# 95   14.175186    5.509355    14.943494   0.572483   0.150822       0.165530
# 96   14.089739    5.552341    14.953666   0.554596   0.138597       0.152338
# 97   14.132463    5.530848    14.948580   0.563539   0.144709       0.158934
# 98   14.111101    5.541595    14.951123   0.559067   0.141653       0.155636
# 99   14.121782    5.536221    14.949852   0.561303   0.143181       0.157285
# 100  14.116442    5.538908    14.950488   0.560185   0.142417       0.156461
# 101  14.119112    5.537565    14.950170   0.560744   0.142799       0.156873
# 102  14.117777    5.538236    14.950329   0.560465   0.142608       0.156667
# 103  14.118444    5.537901    14.950249   0.560605   0.142704       0.156770
# 104  14.118110    5.538068    14.950289   0.560535   0.142656       0.156718
# 105  14.118277    5.537985    14.950269   0.560570   0.142680       0.156744
# 106  14.118194    5.538026    14.950279   0.560552   0.142668       0.156731
# 107  14.118236    5.538006    14.950274   0.560561   0.142674       0.156738
# 108  14.118215    5.538016    14.950277   0.560557   0.142671       0.156734
# 109  14.118225    5.538011    14.950275   0.560559   0.142672       0.156736
# 110  14.118220    5.538013    14.950276   0.560558   0.142671       0.156735
# 111  14.118223    5.538012    14.950276   0.560558   0.142672       0.156736
# 112  14.118221    5.538013    14.950276   0.560558   0.142672       0.156735
# 113  14.118222    5.538012    14.950276   0.560558   0.142672       0.156736
#
# [38 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling.loc['Chelsea']
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_16028\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\Python\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bunrley'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# ----> 2 matches_rolling.loc['Bunrley']
#
# File f:\Python\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File f:\Python\lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File f:\Python\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File f:\Python\lib\site-packages\pandas\core\generic.py:4228, in NDFrame.xs(self, key, axis, level, drop_level)
#    4225     index = self.index
#    4227 if isinstance(index, MultiIndex):
# -> 4228     loc, new_index = index._get_loc_level(key, level=0)
#    4229     if not drop_level:
#    4230         if lib.is_integer(loc):
#    4231             # Slice index must be an integer or None
#
# File f:\Python\lib\site-packages\pandas\core\indexes\multi.py:3175, in MultiIndex._get_loc_level(self, key, level)
#    3173         return indexer, maybe_mi_droplevels(indexer, ilevels)
#    3174 else:
# -> 3175     indexer = self._get_level_indexer(key, level=level)
#    3176     if (
#    3177         isinstance(key, str)
#    3178         and self.levels[level]._supports_partial_string_indexing
#    3179     ):
#    3180         # check to see if we did an exact lookup vs sliced
#    3181         check = self.levels[level].get_loc(key)
#
# File f:\Python\lib\site-packages\pandas\core\indexes\multi.py:3276, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3273         return slice(i, j, step)
#    3275 else:
# -> 3276     idx = self._get_loc_single_level_index(level_index, key)
#    3278     if level > 0 or self._lexsort_depth == 0:
#    3279         # Desired level is not sorted
#    3280         if isinstance(idx, slice):
#    3281             # test_get_loc_partial_timestamp_multiindex
#
# File f:\Python\lib\site-packages\pandas\core\indexes\multi.py:2865, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2863     return -1
#    2864 else:
# -> 2865     return level_index.get_loc(key)
#
# File f:\Python\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Bunrley'

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#           date   time         round  day venue result   gf   ga  \
# 0   2023-08-12  12:30   Matchweek 1  Sat  Home      W  2.0  1.0
# 1   2023-08-21  20:00   Matchweek 2  Mon  Away      W  1.0  0.0
# 2   2023-08-26  15:00   Matchweek 3  Sat  Home      D  2.0  2.0
# 3   2023-09-03  16:30   Matchweek 4  Sun  Home      W  3.0  1.0
# 4   2023-09-17  16:30   Matchweek 5  Sun  Away      W  1.0  0.0
# ..         ...    ...           ...  ...   ...    ...  ...  ...
# 755 2024-04-20    NaN  Matchweek 34  Sat  Home    NaN  NaN  NaN
# 756 2024-04-27    NaN  Matchweek 35  Sat  Home    NaN  NaN  NaN
# 757 2024-05-04    NaN  Matchweek 36  Sat  Away    NaN  NaN  NaN
# 758 2024-05-11    NaN  Matchweek 37  Sat  Home    NaN  NaN  NaN
# 759 2024-05-19    NaN  Matchweek 38  Sun  Away    NaN  NaN  NaN
#
#             opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 0    Nott'ham Forest  0.8  ...    12         5    1.666667   1.000000
# 1     Crystal Palace  2.0  ...    20         0    1.666667   1.000000
# 2             Fulham  3.2  ...    15         5    1.666667   1.000000
# 3     Manchester Utd  2.3  ...    16         6    1.666667   1.000000
# 4            Everton  1.0  ...    16         6    2.000000   1.000000
# ..               ...  ...  ...   ...       ...         ...        ...
# 755          Arsenal  NaN  ...  <NA>         5    3.000000   0.666667
# 756       Luton Town  NaN  ...  <NA>         5    3.000000   0.666667
# 757  Manchester City  NaN  ...  <NA>         5    3.000000   0.666667
# 758   Crystal Palace  NaN  ...  <NA>         5    3.000000   0.666667
# 759        Liverpool  NaN  ...  <NA>         6    3.000000   0.666667
#
#     sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 0    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 1    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 2    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 3    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 4    16.000000    5.333333    15.066667    0.000000    0.666667       0.666667
# ..         ...         ...          ...         ...         ...            ...
# 755  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 756  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 757  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 758  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 759  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
#
# [760 rows x 38 columns]

# %%
matches_rolling.dropna(subset=['hour'], inplace=True)
matches_rolling
# Out:
#           date   time         round  day venue result   gf   ga  \
# 0   2023-08-12  12:30   Matchweek 1  Sat  Home      W  2.0  1.0
# 1   2023-08-21  20:00   Matchweek 2  Mon  Away      W  1.0  0.0
# 2   2023-08-26  15:00   Matchweek 3  Sat  Home      D  2.0  2.0
# 3   2023-09-03  16:30   Matchweek 4  Sun  Home      W  3.0  1.0
# 4   2023-09-17  16:30   Matchweek 5  Sun  Away      W  1.0  0.0
# ..         ...    ...           ...  ...   ...    ...  ...  ...
# 744 2024-02-04  14:00  Matchweek 23  Sun  Away    NaN  NaN  NaN
# 745 2024-02-10  15:00  Matchweek 24  Sat  Home    NaN  NaN  NaN
# 746 2024-02-17  15:00  Matchweek 25  Sat  Away    NaN  NaN  NaN
# 747 2024-02-25  13:30  Matchweek 26  Sun  Home    NaN  NaN  NaN
# 748 2024-03-02  15:00  Matchweek 27  Sat  Away    NaN  NaN  NaN
#
#             opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 0    Nott'ham Forest  0.8  ...    12         5    1.666667   1.000000
# 1     Crystal Palace  2.0  ...    20         0    1.666667   1.000000
# 2             Fulham  3.2  ...    15         5    1.666667   1.000000
# 3     Manchester Utd  2.3  ...    16         6    1.666667   1.000000
# 4            Everton  1.0  ...    16         6    2.000000   1.000000
# ..               ...  ...  ...   ...       ...         ...        ...
# 744          Chelsea  NaN  ...    14         6    3.000000   0.666667
# 745        Brentford  NaN  ...    15         5    3.000000   0.666667
# 746        Tottenham  NaN  ...    15         5    3.000000   0.666667
# 747    Sheffield Utd  NaN  ...    13         6    3.000000   0.666667
# 748    Newcastle Utd  NaN  ...    15         5    3.000000   0.666667
#
#     sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 0    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 1    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 2    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 3    15.333333    6.000000    16.433333    0.000000    0.666667       0.666667
# 4    16.000000    5.333333    15.066667    0.000000    0.666667       0.666667
# ..         ...         ...          ...         ...         ...            ...
# 744  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 745  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 746  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 747  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
# 748  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
#
# [538 rows x 38 columns]

# %%
matches_rolling[matches_rolling["round"]=="Matchweek 21"]
# Out:
#           date   time         round  day venue result  gf  ga  \
# 20  2024-01-20  12:30  Matchweek 21  Sat  Home    NaN NaN NaN
# 58  2024-01-14  14:00  Matchweek 21  Sun  Away    NaN NaN NaN
# 96  2024-01-21  16:30  Matchweek 21  Sun  Home    NaN NaN NaN
# 134 2024-01-20  17:30  Matchweek 21  Sat  Home    NaN NaN NaN
# 172 2024-01-22  19:45  Matchweek 21  Mon  Home    NaN NaN NaN
# 210 2024-01-15  19:45  Matchweek 21  Mon  Home    NaN NaN NaN
# 248 2024-01-13  12:30  Matchweek 21  Sat  Home    NaN NaN NaN
# 286 2024-01-20  12:30  Matchweek 21  Sat  Away    NaN NaN NaN
# 324 2024-01-14  14:00  Matchweek 21  Sun  Home    NaN NaN NaN
# 362 2024-01-13  12:30  Matchweek 21  Sat  Away    NaN NaN NaN
# 400 2024-01-21  16:30  Matchweek 21  Sun  Away    NaN NaN NaN
# 438 2024-01-15  19:45  Matchweek 21  Mon  Away    NaN NaN NaN
# 476 2024-01-13  17:30  Matchweek 21  Sat  Away    NaN NaN NaN
# 514 2024-01-14  16:30  Matchweek 21  Sun  Home    NaN NaN NaN
# 552 2024-01-13  17:30  Matchweek 21  Sat  Home    NaN NaN NaN
# 590 2024-01-20  17:30  Matchweek 21  Sat  Away    NaN NaN NaN
# 628 2024-01-21  14:00  Matchweek 21  Sun  Home    NaN NaN NaN
# 666 2024-01-14  16:30  Matchweek 21  Sun  Away    NaN NaN NaN
# 704 2024-01-21  14:00  Matchweek 21  Sun  Away    NaN NaN NaN
# 742 2024-01-22  19:45  Matchweek 21  Mon  Away    NaN NaN NaN
#
#             opponent  xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 20    Crystal Palace NaN  ...    12         5    0.666667   1.666667
# 58           Everton NaN  ...    14         6    2.000000   2.000000
# 96         Liverpool NaN  ...    16         6    2.333333   1.666667
# 134  Nott'ham Forest NaN  ...    17         5    0.666667   1.666667
# 172           Wolves NaN  ...    19         0    1.666667   1.000000
# 210       Luton Town NaN  ...    19         0    1.333333   1.666667
# 248           Fulham NaN  ...    12         5    2.000000   1.666667
# 286          Arsenal NaN  ...    12         5    1.666667   1.333333
# 324      Aston Villa NaN  ...    14         6    0.666667   2.666667
# 362          Chelsea NaN  ...    12         5    0.666667   2.000000
# 400      Bournemouth NaN  ...    16         6    2.333333   1.000000
# 438          Burnley NaN  ...    19         0    2.000000   1.666667
# 476    Newcastle Utd NaN  ...    17         5    1.333333   1.333333
# 514        Tottenham NaN  ...    16         6    1.333333   2.000000
# 552  Manchester City NaN  ...    17         5    1.000000   2.666667
# 590        Brentford NaN  ...    17         5    2.333333   1.666667
# 628         West Ham NaN  ...    14         6    1.000000   2.000000
# 666   Manchester Utd NaN  ...    16         6    2.333333   2.000000
# 704    Sheffield Utd NaN  ...    14         6    1.333333   0.000000
# 742         Brighton NaN  ...    19         0    3.000000   0.666667
#
#     sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  pkatt_rolling
# 20   18.666667    4.333333    16.466667    0.333333    0.000000       0.000000
# 58   13.333333    4.333333    16.333333    0.666667    0.333333       0.333333
# 96   19.000000    4.333333    17.200000    0.666667    0.333333       0.333333
# 134   7.000000    2.333333    15.833333    0.000000    0.333333       0.333333
# 172  17.666667    7.000000    15.733333    0.000000    0.666667       0.666667
# 210   8.333333    2.333333    17.200000    0.000000    0.000000       0.000000
# 248  12.000000    4.666667    16.733333    0.333333    0.333333       0.333333
# 286  12.333333    4.666667    16.400000    0.666667    0.000000       0.000000
# 324  11.666667    3.333333    16.333333    0.000000    0.000000       0.000000
# 362  14.000000    4.000000    18.700000    1.000000    0.000000       0.000000
# 400  21.333333    8.333333    17.900000    0.333333    0.333333       0.666667
# 438  14.333333    5.000000    16.300000    0.666667    0.000000       0.000000
# 476  13.000000    5.666667    14.766667    0.333333    0.000000       0.000000
# 514  11.333333    5.000000    17.866667    0.333333    0.000000       0.000000
# 552  12.666667    3.333333    14.466667    0.333333    0.333333       0.333333
# 590  11.333333    4.000000    16.200000    0.000000    0.000000       0.000000
# 628  10.000000    2.666667    16.966667    0.333333    0.000000       0.000000
# 666  14.666667    5.000000    15.000000    0.333333    0.000000       0.000000
# 704   7.666667    3.000000    15.733333    0.000000    0.000000       0.333333
# 742  12.333333    5.666667    15.966667    0.333333    0.000000       0.000000
#
# [20 rows x 38 columns]

# %%
def make_predictions(data, predictors):
    rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
    train = data[data["date"]<='2024-01-02']
    test = data[data["date"] > '2024-01-02']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index=test.index)
    predicao = pd.DataFrame(dict(prediction=preds), index=test.index)
    error = precision_score(test["target"], preds, average='micro')
    return combined, error, predicao

# %%
combined, error, predicao = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.6642857142857143

# %%
predicao
# Out:
#      prediction
# 20            1
# 21            0
# 22            0
# 23            0
# 24            1
# ..          ...
# 744           0
# 745           0
# 746           0
# 747           1
# 748           0
#
# [140 rows x 1 columns]

# %%
predicao = predicao.merge(matches_rolling[["date", "round", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
predicao[predicao["round"] == "Matchweek 21"].sort_values("date")
# Out:
#      prediction       date         round                      team  \
# 362           0 2024-01-13  Matchweek 21                    Fulham
# 552           0 2024-01-13  Matchweek 21          Newcastle United
# 248           1 2024-01-13  Matchweek 21                   Chelsea
# 476           0 2024-01-13  Matchweek 21           Manchester City
# 58            1 2024-01-14  Matchweek 21               Aston Villa
# 666           0 2024-01-14  Matchweek 21         Tottenham Hotspur
# 514           0 2024-01-14  Matchweek 21         Manchester United
# 324           0 2024-01-14  Matchweek 21                   Everton
# 210           0 2024-01-15  Matchweek 21                   Burnley
# 438           1 2024-01-15  Matchweek 21                Luton Town
# 590           0 2024-01-20  Matchweek 21         Nottingham Forest
# 20            1 2024-01-20  Matchweek 21                   Arsenal
# 286           0 2024-01-20  Matchweek 21            Crystal Palace
# 134           0 2024-01-20  Matchweek 21                 Brentford
# 704           0 2024-01-21  Matchweek 21           West Ham United
# 628           0 2024-01-21  Matchweek 21          Sheffield United
# 96            1 2024-01-21  Matchweek 21               Bournemouth
# 400           0 2024-01-21  Matchweek 21                 Liverpool
# 172           1 2024-01-22  Matchweek 21  Brighton and Hove Albion
# 742           0 2024-01-22  Matchweek 21   Wolverhampton Wanderers
#
#             opponent result           new_team
# 362          Chelsea    NaN             Fulham
# 552  Manchester City    NaN      Newcastle Utd
# 248           Fulham    NaN            Chelsea
# 476    Newcastle Utd    NaN    Manchester City
# 58           Everton    NaN        Aston Villa
# 666   Manchester Utd    NaN           Totteham
# 514        Tottenham    NaN     Manchester Utd
# 324      Aston Villa    NaN            Everton
# 210       Luton Town    NaN            Burnley
# 438          Burnley    NaN         Luton Town
# 590        Brentford    NaN  Nottingham Forest
# 20    Crystal Palace    NaN            Arsenal
# 286          Arsenal    NaN     Crystal Palace
# 134  Nott'ham Forest    NaN          Brentford
# 704    Sheffield Utd    NaN           West Ham
# 628         West Ham    NaN   Sheffield United
# 96         Liverpool    NaN        Bournemouth
# 400      Bournemouth    NaN          Liverpool
# 172           Wolves    NaN           Brighton
# 742         Brighton    NaN             Wolves

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values={
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Totteham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
predicao["new_team"] = predicao["team"].map(mapping)

# %%
merged = predicao.merge(predicao, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[merged["round_x"] == "Matchweek 21"].sort_values('date')
# Out:
#      prediction_x       date       round_x                    team_x  \
# 98              0 2024-01-13  Matchweek 21          Newcastle United
# 84              0 2024-01-13  Matchweek 21           Manchester City
# 42              1 2024-01-13  Matchweek 21                   Chelsea
# 63              0 2024-01-13  Matchweek 21                    Fulham
# 56              0 2024-01-14  Matchweek 21                   Everton
# 7               1 2024-01-14  Matchweek 21               Aston Villa
# 91              0 2024-01-14  Matchweek 21         Manchester United
# 35              0 2024-01-15  Matchweek 21                   Burnley
# 77              1 2024-01-15  Matchweek 21                Luton Town
# 0               1 2024-01-20  Matchweek 21                   Arsenal
# 49              0 2024-01-20  Matchweek 21            Crystal Palace
# 21              0 2024-01-20  Matchweek 21                 Brentford
# 70              0 2024-01-21  Matchweek 21                 Liverpool
# 14              1 2024-01-21  Matchweek 21               Bournemouth
# 105             0 2024-01-21  Matchweek 21           West Ham United
# 28              1 2024-01-22  Matchweek 21  Brighton and Hove Albion
# 112             0 2024-01-22  Matchweek 21   Wolverhampton Wanderers
#
#           opponent_x result_x       new_team_x  prediction_y       round_y  \
# 98   Manchester City      NaN    Newcastle Utd             0  Matchweek 21
# 84     Newcastle Utd      NaN  Manchester City             0  Matchweek 21
# 42            Fulham      NaN          Chelsea             0  Matchweek 21
# 63           Chelsea      NaN           Fulham             1  Matchweek 21
# 56       Aston Villa      NaN          Everton             1  Matchweek 21
# 7            Everton      NaN      Aston Villa             0  Matchweek 21
# 91         Tottenham      NaN   Manchester Utd             0  Matchweek 21
# 35        Luton Town      NaN          Burnley             1  Matchweek 21
# 77           Burnley      NaN       Luton Town             0  Matchweek 21
# 0     Crystal Palace      NaN          Arsenal             0  Matchweek 21
# 49           Arsenal      NaN   Crystal Palace             1  Matchweek 21
# 21   Nott'ham Forest      NaN        Brentford             0  Matchweek 21
# 70       Bournemouth      NaN        Liverpool             1  Matchweek 21
# 14         Liverpool      NaN      Bournemouth             0  Matchweek 21
# 105    Sheffield Utd      NaN         West Ham             0  Matchweek 21
# 28            Wolves      NaN         Brighton             0  Matchweek 21
# 112         Brighton      NaN           Wolves             1  Matchweek 21
#
#                        team_y       opponent_y result_y         new_team_y
# 98            Manchester City    Newcastle Utd      NaN    Manchester City
# 84           Newcastle United  Manchester City      NaN      Newcastle Utd
# 42                     Fulham          Chelsea      NaN             Fulham
# 63                    Chelsea           Fulham      NaN            Chelsea
# 56                Aston Villa          Everton      NaN        Aston Villa
# 7                     Everton      Aston Villa      NaN            Everton
# 91          Tottenham Hotspur   Manchester Utd      NaN           Totteham
# 35                 Luton Town          Burnley      NaN         Luton Town
# 77                    Burnley       Luton Town      NaN            Burnley
# 0              Crystal Palace          Arsenal      NaN     Crystal Palace
# 49                    Arsenal   Crystal Palace      NaN            Arsenal
# 21          Nottingham Forest        Brentford      NaN  Nottingham Forest
# 70                Bournemouth        Liverpool      NaN        Bournemouth
# 14                  Liverpool      Bournemouth      NaN          Liverpool
# 105          Sheffield United         West Ham      NaN   Sheffield United
# 28    Wolverhampton Wanderers         Brighton      NaN             Wolves
# 112  Brighton and Hove Albion           Wolves      NaN           Brighton

# %%
len(merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0)])
# Out:
# 35

# %%
100/170
# Out:
# 0.5882352941176471
