# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
matches = pd.read_csv("./data/brasileiro.csv", encoding='utf-8')

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result  gf  ga  \
# 0  2023-04-15  16:00  Série A  Matchweek 1  Sat  Home      W   2   1
# 1  2023-04-23  16:00  Série A  Matchweek 2  Sun  Away      D   2   2
# 2  2023-04-29  18:30  Série A  Matchweek 3  Sat  Home      W   2   1
# 3  2023-05-07  18:30  Série A  Matchweek 4  Sun  Away      W   5   0
# 4  2023-05-10  21:30  Série A  Matchweek 5  Wed  Home      W   4   1
#
#         opponent  ...  carries   cpa  crdy  crdr fls fld off  won%  season  \
# 0         Cuiabá  ...    313.0  10.0     4     1  23  12   3  41.7    2024
# 1  Vasco da Gama  ...    378.0   2.0     3     0  15  18   0  56.8    2024
# 2    Corinthians  ...    448.0   4.0     3     0  20  15   0  53.8    2024
# 3          Goiás  ...    419.0   8.0     6     0  29  13   1  65.0    2024
# 4         Grêmio  ...    473.0   8.0     2     0  10  12   2  60.9    2024
#
#         team
# 0  Palmeiras
# 1  Palmeiras
# 2  Palmeiras
# 3  Palmeiras
# 4  Palmeiras
#
# [5 rows x 58 columns]

# %%
print(matches.shape)
# Out:
# (760, 58)

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   38
# Aston Villa                 38
# Burnley                     38
# Luton Town                  38
# Everton                     38
# Brentford                   38
# Nottingham Forest           38
# Crystal Palace              38
# Fulham                      38
# Bournemouth                 38
# Wolverhampton Wanderers     38
# Chelsea                     38
# Newcastle United            38
# Manchester United           38
# Brighton and Hove Albion    38
# West Ham United             38
# Tottenham Hotspur           38
# Arsenal                     38
# Manchester City             38
# Sheffield United            38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# 5   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      W  3.0
# 6   2023-09-30  17:30  Premier League   Matchweek 7  Sat  Away      L  1.0
# 7   2023-10-08  14:00  Premier League   Matchweek 8  Sun  Away      D  2.0
# 8   2023-10-21  12:30  Premier League   Matchweek 9  Sat  Home      W  2.0
# 9   2023-10-29  14:00  Premier League  Matchweek 10  Sun  Home      W  3.0
# 10  2023-11-05  16:30  Premier League  Matchweek 11  Sun  Away      D  1.0
# 11  2023-11-12  14:00  Premier League  Matchweek 12  Sun  Home      W  3.0
# 12  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Away      D  1.0
# 13  2023-12-03  14:00  Premier League  Matchweek 14  Sun  Home      W  4.0
# 14  2023-12-06  19:30  Premier League  Matchweek 15  Wed  Away      W  2.0
# 15  2023-12-09  12:30  Premier League  Matchweek 16  Sat  Away      W  2.0
# 16  2023-12-17  16:30  Premier League  Matchweek 17  Sun  Home      D  0.0
# 17  2023-12-23  17:30  Premier League  Matchweek 18  Sat  Home      D  1.0
# 18  2023-12-26  17:30  Premier League  Matchweek 19  Tue  Away      W  2.0
# 19  2024-01-01  20:00  Premier League  Matchweek 20  Mon  Home      W  4.0
# 20  2024-01-21  16:30  Premier League  Matchweek 21  Sun  Away    NaN  NaN
# 21  2024-01-31  20:15  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 22  2024-02-04  16:30  Premier League  Matchweek 23  Sun  Away    NaN  NaN
# 23  2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 24  2024-02-17  12:30  Premier League  Matchweek 25  Sat  Away    NaN  NaN
# 25  2024-02-24  15:00  Premier League  Matchweek 26  Sat  Home    NaN  NaN
# 26  2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away    NaN  NaN
# 27  2024-03-09    NaN  Premier League  Matchweek 28  Sat  Home    NaN  NaN
# 28  2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 29  2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 30  2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 31  2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 32  2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 33  2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 34  2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 35  2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 36  2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 37  2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#      ga         opponent  ...  carries   cpa  crdy  crdr   fls   fld  off  \
# 0   1.0          Chelsea  ...    286.0   6.0   3.0   0.0  13.0   5.0  5.0
# 1   1.0      Bournemouth  ...    429.0   6.0   1.0   1.0  11.0  13.0  0.0
# 2   1.0    Newcastle Utd  ...    279.0   5.0   2.0   1.0  10.0  15.0  1.0
# 3   0.0      Aston Villa  ...    598.0  10.0   0.0   0.0  12.0   7.0  6.0
# 4   1.0           Wolves  ...    538.0   7.0   3.0   0.0   4.0   9.0  0.0
# 5   1.0         West Ham  ...    566.0   7.0   0.0   0.0  12.0  13.0  2.0
# 6   2.0        Tottenham  ...    323.0   5.0   6.0   2.0  17.0  11.0  1.0
# 7   2.0         Brighton  ...    383.0   3.0   2.0   0.0  20.0  12.0  0.0
# 8   0.0          Everton  ...    502.0  14.0   1.0   0.0   9.0   8.0  2.0
# 9   0.0  Nott'ham Forest  ...    483.0   5.0   2.0   0.0   9.0  13.0  1.0
# 10  1.0       Luton Town  ...    593.0   5.0   1.0   0.0  13.0   5.0  1.0
# 11  0.0        Brentford  ...    418.0   5.0   1.0   0.0  16.0  10.0  2.0
# 12  1.0  Manchester City  ...    333.0   6.0   3.0   0.0  11.0   8.0  4.0
# 13  3.0           Fulham  ...    479.0   6.0   0.0   0.0   6.0   7.0  5.0
# 14  0.0    Sheffield Utd  ...    526.0   6.0   3.0   0.0   8.0  12.0  4.0
# 15  1.0   Crystal Palace  ...    587.0   3.0   2.0   0.0  17.0  17.0  6.0
# 16  0.0   Manchester Utd  ...    521.0   7.0   2.0   0.0  13.0   8.0  4.0
# 17  1.0          Arsenal  ...    333.0   5.0   2.0   0.0  13.0  13.0  1.0
# 18  0.0          Burnley  ...    483.0   7.0   1.0   0.0  10.0   7.0  4.0
# 19  2.0    Newcastle Utd  ...    419.0  19.0   3.0   0.0  16.0  15.0  1.0
# 20  NaN      Bournemouth  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 21  NaN          Chelsea  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 22  NaN          Arsenal  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 23  NaN          Burnley  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 24  NaN        Brentford  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 25  NaN       Luton Town  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 26  NaN  Nott'ham Forest  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 27  NaN  Manchester City  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 28  NaN          Everton  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 29  NaN         Brighton  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 30  NaN    Sheffield Utd  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 31  NaN   Manchester Utd  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 32  NaN   Crystal Palace  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 33  NaN           Fulham  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 34  NaN         West Ham  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 35  NaN        Tottenham  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 36  NaN      Aston Villa  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 37  NaN           Wolves  ...      NaN   NaN   NaN   NaN   NaN   NaN  NaN
#
#     won% season       team
# 0   35.3   2024  Liverpool
# 1   63.3   2024  Liverpool
# 2   47.1   2024  Liverpool
# 3   80.0   2024  Liverpool
# 4   61.1   2024  Liverpool
# 5   74.3   2024  Liverpool
# 6   52.9   2024  Liverpool
# 7   54.5   2024  Liverpool
# 8   50.0   2024  Liverpool
# 9   56.7   2024  Liverpool
# 10  61.8   2024  Liverpool
# 11  51.3   2024  Liverpool
# 12  30.4   2024  Liverpool
# 13  44.4   2024  Liverpool
# 14  68.4   2024  Liverpool
# 15  56.5   2024  Liverpool
# 16  42.3   2024  Liverpool
# 17  78.9   2024  Liverpool
# 18  67.4   2024  Liverpool
# 19  47.4   2024  Liverpool
# 20   NaN   2024  Liverpool
# 21   NaN   2024  Liverpool
# 22   NaN   2024  Liverpool
# 23   NaN   2024  Liverpool
# 24   NaN   2024  Liverpool
# 25   NaN   2024  Liverpool
# 26   NaN   2024  Liverpool
# 27   NaN   2024  Liverpool
# 28   NaN   2024  Liverpool
# 29   NaN   2024  Liverpool
# 30   NaN   2024  Liverpool
# 31   NaN   2024  Liverpool
# 32   NaN   2024  Liverpool
# 33   NaN   2024  Liverpool
# 34   NaN   2024  Liverpool
# 35   NaN   2024  Liverpool
# 36   NaN   2024  Liverpool
# 37   NaN   2024  Liverpool
#
# [38 rows x 58 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     20
# Matchweek 29    20
# Matchweek 22    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 28    20
# Matchweek 30    20
# Matchweek 2     20
# Matchweek 31    20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 21    20
# Matchweek 20    20
# Matchweek 19    20
# Matchweek 18    20
# Matchweek 3     20
# Matchweek 4     20
# Matchweek 5     20
# Matchweek 6     20
# Matchweek 7     20
# Matchweek 8     20
# Matchweek 9     20
# Matchweek 10    20
# Matchweek 11    20
# Matchweek 12    20
# Matchweek 13    20
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# sota            float64
# save%           float64
# pksv            float64
# cmp%            float64
# cmp%.1          float64
# cmp%.2          float64
# cmp%.3          float64
# ppa             float64
# crspa           float64
# prgp            float64
# sca             float64
# gca             float64
# tklw            float64
# tkl%            float64
# shbk            float64
# pass            float64
# int             float64
# tkl+int         float64
# clr             float64
# err             float64
# touches         float64
# def pen         float64
# att pen         float64
# carries         float64
# cpa             float64
# crdy            float64
# crdr            float64
# fls             float64
# fld             float64
# off             float64
# won%            float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                     int64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                       int64
# sot                      int64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# sota                     int64
# save%                  float64
# pksv                     int64
# cmp%                   float64
# cmp%.1                 float64
# cmp%.2                 float64
# cmp%.3                 float64
# ppa                    float64
# crspa                  float64
# prgp                   float64
# sca                    float64
# gca                    float64
# tklw                     int64
# tkl%                   float64
# shbk                   float64
# pass                   float64
# int                      int64
# tkl+int                  int64
# clr                    float64
# err                    float64
# touches                float64
# def pen                float64
# att pen                float64
# carries                float64
# cpa                    float64
# crdy                     int64
# crdr                     int64
# fls                      int64
# fld                      int64
# off                      int64
# won%                   float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#           date   time     comp         round  day venue result  gf  ga  \
# 0   2023-04-15  16:00  Série A   Matchweek 1  Sat  Home      W   2   1
# 1   2023-04-23  16:00  Série A   Matchweek 2  Sun  Away      D   2   2
# 2   2023-04-29  18:30  Série A   Matchweek 3  Sat  Home      W   2   1
# 3   2023-05-07  18:30  Série A   Matchweek 4  Sun  Away      W   5   0
# 4   2023-05-10  21:30  Série A   Matchweek 5  Wed  Home      W   4   1
# ..         ...    ...      ...           ...  ...   ...    ...  ..  ..
# 755 2023-11-12  18:30  Série A  Matchweek 34  Sun  Away      L   1   2
# 756 2023-11-26  18:30  Série A  Matchweek 35  Sun  Home      L   0   3
# 757 2023-11-29  21:30  Série A  Matchweek 36  Wed  Away      L   0   4
# 758 2023-12-03  18:30  Série A  Matchweek 37  Sun  Home      W   3   2
# 759 2023-12-06  19:00  Série A  Matchweek 38  Wed  Away      L   0   1
#
#           opponent  ...  fls  fld  off  won% season        team target  \
# 0           Cuiabá  ...   23   12    3  41.7   2024   Palmeiras      1
# 1    Vasco da Gama  ...   15   18    0  56.8   2024   Palmeiras      0
# 2      Corinthians  ...   20   15    0  53.8   2024   Palmeiras      1
# 3            Goiás  ...   29   13    1  65.0   2024   Palmeiras      1
# 4           Grêmio  ...   10   12    2  60.9   2024   Palmeiras      1
# ..             ...  ...  ...  ...  ...   ...    ...         ...    ...
# 755  Vasco da Gama  ...   12   11    0  64.7   2024  America MG      0
# 756       Flamengo  ...    9   13    0  46.7   2024  America MG      0
# 757      Palmeiras  ...   15   10    2  47.6   2024  America MG      0
# 758          Bahia  ...   15    4    1  54.1   2024  America MG      1
# 759          Goiás  ...   13   12    2  66.7   2024  America MG      0
#
#     venue_code  opp_code  day_code
# 0            1         9         5
# 1            0        19         6
# 2            1         6         5
# 3            0        13         6
# 4            1        14         2
# ..         ...       ...       ...
# 755          0        19         6
# 756          1        10         6
# 757          0        16         2
# 758          1         3         6
# 759          0        13         2
#
# [760 rows x 62 columns]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2023-11-01']
test = matches[(matches["date"] >='2023-11-01')]
test.dropna(subset=['result'], inplace=True)
predictors =["venue_code", "opp_code", "day_code"]
rf.fit(train[predictors], train["target"])
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\248916938.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.dropna(subset=['result'], inplace=True)
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6036585365853658

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           75  27
# 1           38  24

# %%
precision_score(test["target"], preds, average='micro')
# Out:
# 0.6036585365853658

# %%
groupsed_matches = matches.groupby("team")

# %%
group = groupsed_matches.get_group("Palmeiras")
group
# Out:
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-04-15  16:00  Série A   Matchweek 1  Sat  Home      W   2   1
# 1  2023-04-23  16:00  Série A   Matchweek 2  Sun  Away      D   2   2
# 2  2023-04-29  18:30  Série A   Matchweek 3  Sat  Home      W   2   1
# 3  2023-05-07  18:30  Série A   Matchweek 4  Sun  Away      W   5   0
# 4  2023-05-10  21:30  Série A   Matchweek 5  Wed  Home      W   4   1
# 5  2023-05-13  18:30  Série A   Matchweek 6  Sat  Home      D   1   1
# 6  2023-05-20  21:00  Série A   Matchweek 7  Sat  Away      D   0   0
# 7  2023-05-28  18:30  Série A   Matchweek 8  Sun  Away      D   1   1
# 8  2023-06-04  18:30  Série A   Matchweek 9  Sun  Home      W   3   1
# 9  2023-06-11  16:00  Série A  Matchweek 10  Sun  Away      W   2   0
# 10 2023-06-21  21:30  Série A  Matchweek 11  Wed  Away      L   0   1
# 11 2023-06-25  16:00  Série A  Matchweek 12  Sun  Home      L   0   1
# 12 2023-07-02  16:00  Série A  Matchweek 13  Sun  Away      D   2   2
# 13 2023-07-08  21:00  Série A  Matchweek 14  Sat  Home      D   1   1
# 14 2023-07-16  18:30  Série A  Matchweek 15  Sun  Away      D   0   0
# 15 2023-07-22  16:00  Série A  Matchweek 16  Sat  Home      W   3   1
# 19            Cuiabá  ...   18   16    1  42.9   2024  Palmeiras      1
# 20     Vasco da Gama  ...   20   15    2  39.3   2024  Palmeiras      1
# 21       Corinthians  ...   17   13    1  40.7   2024  Palmeiras      0
# 22             Goiás  ...   12   19    2  48.6   2024  Palmeiras      1
# 23            Grêmio  ...   14   15    3  58.6   2024  Palmeiras      0
# 24        Bragantino  ...   20   12    3  33.3   2024  Palmeiras      0
# 25            Santos  ...    8   10    7  48.5   2024  Palmeiras      0
# 26  Atlético Mineiro  ...   17   17    2  61.3   2024  Palmeiras      0
# 27          Coritiba  ...   18   13    2  46.2   2024  Palmeiras      1
# 28         São Paulo  ...   15   15    3  64.3   2024  Palmeiras      1
# 29             Bahia  ...   15   17    5  52.8   2024  Palmeiras      1
# 30     Botafogo (RJ)  ...   13   10    3  45.5   2024  Palmeiras      1
# 31    Ath Paranaense  ...   17   17    2  53.8   2024  Palmeiras      1
# 32          Flamengo  ...   17   13    3  53.8   2024  Palmeiras      0
# 33     Internacional  ...   13   13    3  77.3   2024  Palmeiras      1
# 34         Fortaleza  ...   11   18    1  42.9   2024  Palmeiras      0
# 35      América (MG)  ...   10   15    2  52.4   2024  Palmeiras      1
# 36        Fluminense  ...   11   11    1  38.5   2024  Palmeiras      1
# 37          Cruzeiro  ...   19    9    0  60.9   2024  Palmeiras      0
#
#    venue_code  opp_code  day_code
# 0           1         9         5
# 1           0        19         6
# 2           1         6         5
# 3           0        13         6
# 4           1        14         2
# 5           1         5         5
# 6           0        17         5
# 7           0         2         6
# 8           1         7         6
# 9           0        18         6
# 10          0         3         2
# 11          1         4         6
# 12          0         1         6
# 13          1        10         5
# 14          0        15         6
# 15          1        12         5
# 16          0         0         6
# 17          0        11         5
# 18          1         8         0
# 19          0         9         5
# 20          1        19         6
# 21          0         6         6
# 22          1        13         4
# 23          0        14         3
# 24          0         5         6
# 25          1        17         6
# 26          1         2         3
# 27          0         7         6
# 28          1        18         2
# 29          1         3         5
# 30          0         4         2
# 31          1         1         5
# 32          0        10         2
# 33          1        15         5
# 34          0        12         6
# 35          1         0         2
# 36          1        11         6
# 37          0         8         2
#
# [38 rows x 62 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
    group[new_cols] = rolling_stats
    nan_index = group[group[new_cols].isna()].index
    for idx in nan_index:
        for col in new_cols:  # Ignora a coluna 'Rodada'
            group.at[idx, f'{col}'] = group.loc[idx - 3 + 1:idx, col].mean()
    return group

# %%
group.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'sota', 'save%', 'pksv', 'cmp%', 'cmp%.1', 'cmp%.2', 'cmp%.3',
#        'ppa', 'crspa', 'prgp', 'sca', 'gca', 'tklw', 'tkl%', 'shbk', 'pass',
#        'int', 'tkl+int', 'clr', 'err', 'touches', 'def pen', 'att pen',
#        'carries', 'cpa', 'crdy', 'crdr', 'fls', 'fld', 'off', 'won%', 'season',
#        'team', 'target', 'venue_code', 'opp_code', 'day_code'],
#       dtype='object')

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt","sota", "save%", "pksv", "cmp%", "ppa", "crspa", "prgp","sca", "gca", "tklw", "tkl%", "shbk", "pass", "int", "tkl+int", "clr", "err", "touches", "def pen", "att pen", "carries", "cpa", "crdy", "crdr", "fls", "fld", "off", "won%"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling',
#  'sota_rolling',
#  'save%_rolling',
#  'pksv_rolling',
#  'cmp%_rolling',
#  'ppa_rolling',
#  'crspa_rolling',
#  'prgp_rolling',
#  'sca_rolling',
#  'gca_rolling',
#  'tklw_rolling',
#  'tkl%_rolling',
#  'shbk_rolling',
#  'pass_rolling',
#  'int_rolling',
#  'tkl+int_rolling',
#  'clr_rolling',
#  'err_rolling',
#  'touches_rolling',
#  'def pen_rolling',
#  'att pen_rolling',
#  'carries_rolling',
#  'cpa_rolling',
#  'crdy_rolling',
#  'crdr_rolling',
#  'fls_rolling',
#  'fld_rolling',
#  'off_rolling',
#  'won%_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
#          date   time     comp         round  day venue result  gf  ga  \
# 0  2023-04-15  16:00  Série A   Matchweek 1  Sat  Home      W   2   1
# 1  2023-04-23  16:00  Série A   Matchweek 2  Sun  Away      D   2   2
# 2  2023-04-29  18:30  Série A   Matchweek 3  Sat  Home      W   2   1
# 3  2023-05-07  18:30  Série A   Matchweek 4  Sun  Away      W   5   0
# 4  2023-05-10  21:30  Série A   Matchweek 5  Wed  Home      W   4   1
# 5  2023-05-13  18:30  Série A   Matchweek 6  Sat  Home      D   1   1
# 6  2023-05-20  21:00  Série A   Matchweek 7  Sat  Away      D   0   0
# 7  2023-05-28  18:30  Série A   Matchweek 8  Sun  Away      D   1   1
# 8  2023-06-04  18:30  Série A   Matchweek 9  Sun  Home      W   3   1
# 9  2023-06-11  16:00  Série A  Matchweek 10  Sun  Away      W   2   0
# 10 2023-06-21  21:30  Série A  Matchweek 11  Wed  Away      L   0   1
# 11 2023-06-25  16:00  Série A  Matchweek 12  Sun  Home      L   0   1
# 12 2023-07-02  16:00  Série A  Matchweek 13  Sun  Away      D   2   2
# 13 2023-07-08  21:00  Série A  Matchweek 14  Sat  Home      D   1   1
# 14 2023-07-16  18:30  Série A  Matchweek 15  Sun  Away      D   0   0
# 15 2023-07-22  16:00  Série A  Matchweek 16  Sat  Home      W   3   1
# 16 2023-07-30  16:00  Série A  Matchweek 17  Sun  Away      W   4   1
# 17 2023-08-05  21:00  Série A  Matchweek 18  Sat  Away      L   1   2
# 18 2023-08-14  19:00  Série A  Matchweek 19  Mon  Home      W   1   0
# 19 2023-08-19  17:30  Série A  Matchweek 20  Sat  Away      W   2   0
# 20 2023-08-27  18:30  Série A  Matchweek 21  Sun  Home      W   1   0
# 21 2023-09-03  16:00  Série A  Matchweek 22  Sun  Away      D   0   0
# 22 2023-09-15  21:30  Série A  Matchweek 23  Fri  Home      W   1   0
# 23 2023-09-21  21:30  Série A  Matchweek 24  Thu  Away      L   0   1
# 24 2023-10-01  18:30  Série A  Matchweek 25  Sun  Away      L   1   2
# 25 2023-10-08  16:00  Série A  Matchweek 26  Sun  Home      L   1   2
# 26 2023-10-19  19:00  Série A  Matchweek 27  Thu  Home      L   0   2
# 27 2023-10-22  18:30  Série A  Matchweek 28  Sun  Away      W   2   0
# 28 2023-10-25  20:00  Série A  Matchweek 29  Wed  Home      W   5   0
# 29 2023-10-28  19:00  Série A  Matchweek 30  Sat  Home      W   1   0
# 30 2023-11-01  21:30  Série A  Matchweek 31  Wed  Away      W   4   3
3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15692\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
#                         date   time     comp         round  day venue result  \
# team
# America MG    722 2023-04-15  16:00  Série A   Matchweek 1  Sat  Home      L
#               723 2023-04-22  18:30  Série A   Matchweek 2  Sat  Away      L
#               724 2023-04-29  18:30  Série A   Matchweek 3  Sat  Away      L
#               725 2023-05-07  11:00  Série A   Matchweek 4  Sun  Home      L
#               726 2023-05-10  19:00  Série A   Matchweek 5  Wed  Away      D
# ...                      ...    ...      ...           ...  ...   ...    ...
# Vasco da Gama 565 2023-11-22  19:00  Série A  Matchweek 33  Wed  Away      D
#               566 2023-11-25  19:30  Série A  Matchweek 35  Sat  Away      D
#               567 2023-11-28  21:30  Série A  Matchweek 36  Tue  Home      L
#               568 2023-12-03  18:30  Série A  Matchweek 37  Sun  Away      L
#               569 2023-12-06  21:30  Série A  Matchweek 38  Wed  Home      W
#
#                    gf  ga        opponent  ...  def pen_rolling  \
# team                                       ...
# America MG    722   0   3      Fluminense  ...        43.000000
#               723   0   3       São Paulo  ...        43.000000
#               724   2   3          Santos  ...        43.000000
#               725   1   2          Cuiabá  ...        43.000000
#               726   2   2      Bragantino  ...        43.000000
# ...                ..  ..             ...  ...              ...
# Vasco da Gama 565   2   2        Cruzeiro  ...        57.494213
#               566   0   0  Ath Paranaense  ...        58.178805
#               567   2   4     Corinthians  ...        59.335450
#               568   0   1          Grêmio  ...        64.838085
#               569   2   1      Bragantino  ...        64.391178
#
#                    att pen_rolling  carries_rolling  cpa_rolling crdy_rolling  \
# team
# America MG    722        25.666667       299.333333     3.000000     3.333333
#               723        25.666667       299.333333     3.000000     3.333333
#               724        25.666667       299.333333     3.000000     3.333333
#               725        25.666667       299.333333     3.000000     3.333333
#               726        25.666667       299.333333     3.000000     3.333333
# ...                            ...              ...          ...          ...
# Vasco da Gama 565        17.618785       337.530039     2.440327     2.948455
#               566        17.188262       330.646520     2.694776     2.472265
#               567        16.157904       314.058853     2.600590     2.140240
#               568        15.115389       301.124013     2.654011     2.093057
#               569        15.757764       302.949844     3.195978     2.188877
#
#                   crdr_rolling fls_rolling fld_rolling  off_rolling  \
# team
# America MG    722     0.000000   17.666667   15.000000     2.000000
#               723     0.000000   17.666667   15.000000     2.000000
#               724     0.000000   17.666667   15.000000     2.000000
#               725     0.000000   17.666667   15.000000     2.000000
#               726     0.000000   17.666667   15.000000     2.000000
# ...                        ...         ...         ...          ...
# Vasco da Gama 565     0.487680   13.981344   12.847189     1.479181
#               566     0.370136   14.194618   12.366430     1.401170
#               567     0.397050   14.391988   12.404540     1.849006
#               568     0.366839   14.084424   12.479212     1.972281
#               569     0.365741   13.603248   11.739028     2.162651
#
#                    won%_rolling
# team
# America MG    722     44.500000
#               723     44.500000
#               724     44.500000
#               725     44.500000
#               726     44.500000
# ...                         ...
# Vasco da Gama 565     47.511741
#               566     45.776211
#               567     46.618206
#               568     47.575917
#               569     48.464708
#
# [760 rows x 98 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#           date   time     comp         round  day venue result  gf  ga  \
# 0   2023-04-15  16:00  Série A   Matchweek 1  Sat  Home      L   0   3
# 1   2023-04-22  18:30  Série A   Matchweek 2  Sat  Away      L   0   3
# 2   2023-04-29  18:30  Série A   Matchweek 3  Sat  Away      L   2   3
# 3   2023-05-07  11:00  Série A   Matchweek 4  Sun  Home      L   1   2
# 4   2023-05-10  19:00  Série A   Matchweek 5  Wed  Away      D   2   2
# ..         ...    ...      ...           ...  ...   ...    ...  ..  ..
# 755 2023-11-22  19:00  Série A  Matchweek 33  Wed  Away      D   2   2
# 756 2023-11-25  19:30  Série A  Matchweek 35  Sat  Away      D   0   0
# 757 2023-11-28  21:30  Série A  Matchweek 36  Tue  Home      L   2   4
# 758 2023-12-03  18:30  Série A  Matchweek 37  Sun  Away      L   0   1
# 759 2023-12-06  21:30  Série A  Matchweek 38  Wed  Home      W   2   1
#
#            opponent  ...  def pen_rolling  att pen_rolling  carries_rolling  \
# 0        Fluminense  ...        43.000000        25.666667       299.333333
# 1         São Paulo  ...        43.000000        25.666667       299.333333
# 2            Santos  ...        43.000000        25.666667       299.333333
# 3            Cuiabá  ...        43.000000        25.666667       299.333333
# 4        Bragantino  ...        43.000000        25.666667       299.333333
# ..              ...  ...              ...              ...              ...
# 755        Cruzeiro  ...        57.494213        17.618785       337.530039
# 756  Ath Paranaense  ...        58.178805        17.188262       330.646520
# 757     Corinthians  ...        59.335450        16.157904       314.058853
# 758          Grêmio  ...        64.838085        15.115389       301.124013
# 759      Bragantino  ...        64.391178        15.757764       302.949844
#
#      cpa_rolling crdy_rolling crdr_rolling fls_rolling fld_rolling  \
# 0       3.000000     3.333333     0.000000   17.666667   15.000000
# 1       3.000000     3.333333     0.000000   17.666667   15.000000
# 2       3.000000     3.333333     0.000000   17.666667   15.000000
# 3       3.000000     3.333333     0.000000   17.666667   15.000000
# 4       3.000000     3.333333     0.000000   17.666667   15.000000
# ..           ...          ...          ...         ...         ...
# 755     2.440327     2.948455     0.487680   13.981344   12.847189
# 756     2.694776     2.472265     0.370136   14.194618   12.366430
# 757     2.600590     2.140240     0.397050   14.391988   12.404540
# 758     2.654011     2.093057     0.366839   14.084424   12.479212
# 759     3.195978     2.188877     0.365741   13.603248   11.739028
#
#      off_rolling  won%_rolling
# 0       2.000000     44.500000
# 1       2.000000     44.500000
# 2       2.000000     44.500000
# 3       2.000000     44.500000
# 4       2.000000     44.500000
# ..           ...           ...
# 755     1.479181     47.511741
# 756     1.401170     45.776211
# 757     1.849006     46.618206
# 758     1.972281     47.575917
# 759     2.162651     48.464708
#
# [760 rows x 98 columns]

# %%
matches_rolling[matches_rolling["round"]=="Matchweek 21"]
# Out:
#           date   time     comp         round  day venue result  gf  ga  \
# 19  2023-08-27  16:00  Série A  Matchweek 21  Sun  Home      W   2   1
# 58  2023-08-27  18:30  Série A  Matchweek 21  Sun  Home      D   2   2
# 96  2023-08-27  16:00  Série A  Matchweek 21  Sun  Home      W   2   0
# 134 2023-08-27  16:00  Série A  Matchweek 21  Sun  Away      L   0   3
# 172 2023-08-27  16:00  Série A  Matchweek 21  Sun  Home      W   3   0
# 210 2023-08-27  11:00  Série A  Matchweek 21  Sun  Home      W   2   0
# 247 2023-08-26  21:00  Série A  Matchweek 21  Sat  Home      D   1   1
# 286 2023-08-27  18:30  Série A  Matchweek 21  Sun  Away      L   1   3
# 590     3.526777     3.427630     0.345679   14.032012   13.113061
# 628     3.567500     2.032378     0.063572   14.930244   17.749659
# 666     3.091995     3.569641     0.111292   18.479152   17.953981
# 704     3.599434     3.248650     0.148395   15.301300   13.145053
# 741     3.454970     2.276375     0.005777   15.290662   14.554770
#
#      off_rolling  won%_rolling
# 19      1.954618     50.644654
# 58      1.513735     50.215857
# 96      1.310473     47.728851
# 134     1.349365     54.421795
# 172     0.538739     52.348242
# 210     0.832658     49.303747
# 247     1.615606     55.202093
# 286     1.668496     44.205584
# 324     1.383043     53.095098
# 362     2.061218     55.050215
# 400     1.490385     53.601391
# 438     1.614356     47.448069
# 476     2.628841     52.595202
# 514     2.098767     53.176723
# 551     1.678309     40.014883
# 590     1.733679     47.751961
# 628     3.536577     47.490832
# 666     1.407803     49.876082
# 704     3.851370     46.439518
# 741     1.753465     50.068495
#
# [20 rows x 98 columns]

# %%
def make_predictions(data, predictors):
    rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
    train = data[data["date"] < '2023-11-01']
    test = data[data["date"] >='2023-11-01']
    #train = data[data["date"] < '2023-12-10']
    #test = data[(data["date"] >= '2023-12-10') & (data["date"] <= '2024-01-02')]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index=test.index)
    predicao = pd.DataFrame(dict(prediction=preds), index=test.index)
    error = precision_score(test["target"], preds, average='micro')
    return combined, error, predicao

# %%
combined, error, predicao = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5853658536585366

# %%
predicao
# Out:
#      prediction
# 30            0
# 31            0
# 32            0
# 33            0
# 34            0
# ..          ...
# 755           0
# 756           0
# 757           0
# 758           0
# 759           0
#
# [164 rows x 1 columns]

# %%
predicao = predicao.merge(matches_rolling[["date", "round", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
predicao[predicao["round"] == "Matchweek 30"].sort_values("date")
# Out:
#      prediction       date         round        team    opponent result
# 336           0 2023-11-18  Matchweek 30    Cruzeiro   Fortaleza      W
# 488           0 2023-11-18  Matchweek 30   Fortaleza    Cruzeiro      L
# 223           0 2023-11-23  Matchweek 30  Bragantino    Flamengo      L
# 413           0 2023-11-23  Matchweek 30    Flamengo  Bragantino      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values={
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Totteham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
predicao["new_team"] = predicao["team"].map(mapping)

# %%
merged = predicao.merge(predicao, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged[merged["round_x"] == "Matchweek 32"].sort_values('date')
# Out:
#     prediction_x       date       round_x         team_x      opponent_x  \
# 0              0 2023-11-04  Matchweek 32          Bahia          Grêmio
# 76             0 2023-11-04  Matchweek 32      Palmeiras  Ath Paranaense
# 8              0 2023-11-05  Matchweek 32     Bragantino     Corinthians
# 17             0 2023-11-05  Matchweek 32    Corinthians      Bragantino
# 25             0 2023-11-05  Matchweek 32       Coritiba           Goiás
# 33             0 2023-11-05  Matchweek 32       Cruzeiro   Internacional
# 42             1 2023-11-05  Matchweek 32       Flamengo       Fortaleza
# 58             1 2023-11-05  Matchweek 32      Fortaleza        Flamengo
# 68             0 2023-11-05  Matchweek 32  Internacional        Cruzeiro
# 84             1 2023-11-06  Matchweek 32         Santos          Cuiabá
# 92             0 2023-11-06  Matchweek 32  Vasco da Gama   Botafogo (RJ)
# 52             0 2023-11-22  Matchweek 32     Fluminense       São Paulo
#
#    result_x     new_team_x  prediction_y       round_y                team_y  \
# 0         L          Bahia             0  Matchweek 32                Gremio
# 76        W      Palmeiras             0  Matchweek 32  Athletico Paranaense
# 8         W     Bragantino             0  Matchweek 32           Corinthians
# 17        L    Corinthians             0  Matchweek 32            Bragantino
# 25        L       Coritiba             0  Matchweek 32                 Goias
# 33        L       Cruzeiro             0  Matchweek 32         Internacional
# 42        W       Flamengo             1  Matchweek 32             Fortaleza
# 58        L      Fortaleza             1  Matchweek 32              Flamengo
# 68        W  Internacional             0  Matchweek 32              Cruzeiro
# 84        D         Santos             0  Matchweek 32                Cuiaba
# 92        W  Vasco da Gama             1  Matchweek 32           Botafogo RJ
# 52        W     Fluminense             0  Matchweek 32             Sao Paulo
#
#        opponent_y result_y            new_team_y
# 0           Bahia        W                Gremio
# 76      Palmeiras        L  Athletico Paranaense
# 8      Bragantino        L           Corinthians
# 17    Corinthians        W            Bragantino
# 25       Coritiba        W                 Goias
# 33       Cruzeiro        W         Internacional
# 42       Flamengo        L             Fortaleza
# 58      Fortaleza        W              Flamengo
# 68  Internacional        L              Cruzeiro
# 84         Santos        D                Cuiaba
# 92  Vasco da Gama        L           Botafogo RJ
# 52     Fluminense        L             Sao Paulo

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0) & (merged["round_x"] == "Matchweek 21")]
# Out:
#      prediction_x       date       round_x           team_x      opponent_x  \
# 0               1 2024-01-20  Matchweek 21          Arsenal  Crystal Palace
# 108             1 2024-01-13  Matchweek 21          Chelsea          Fulham
# 180             1 2024-01-21  Matchweek 21        Liverpool     Bournemouth
# 216             1 2024-01-13  Matchweek 21  Manchester City   Newcastle Utd
#
#     result_x       new_team_x  prediction_y       round_y            team_y  \
# 0        NaN          Arsenal             0  Matchweek 21    Crystal Palace
# 108      NaN          Chelsea             0  Matchweek 21            Fulham
# 180      NaN        Liverpool             0  Matchweek 21       Bournemouth
# 216      NaN  Manchester City             0  Matchweek 21  Newcastle United
#
#           opponent_y result_y      new_team_y
# 0            Arsenal      NaN  Crystal Palace
# 108          Chelsea      NaN          Fulham
# 180        Liverpool      NaN     Bournemouth
# 216  Manchester City      NaN   Newcastle Utd

# %%
merged[(merged["prediction_y"] == 1) & (merged["prediction_x"] ==0) & (merged["round_x"] == "Matchweek 21")]
# Out:
#      prediction_x       date       round_x            team_x       opponent_x  \
# 36              0 2024-01-21  Matchweek 21       Bournemouth        Liverpool
# 54              0 2024-01-20  Matchweek 21         Brentford  Nott'ham Forest
# 126             0 2024-01-20  Matchweek 21    Crystal Palace          Arsenal
# 162             0 2024-01-13  Matchweek 21            Fulham          Chelsea
# 252             0 2024-01-13  Matchweek 21  Newcastle United  Manchester City
#
#     result_x      new_team_x  prediction_y       round_y             team_y  \
# 36       NaN     Bournemouth             1  Matchweek 21          Liverpool
# 54       NaN       Brentford             1  Matchweek 21  Nottingham Forest
# 126      NaN  Crystal Palace             1  Matchweek 21            Arsenal
# 162      NaN          Fulham             1  Matchweek 21            Chelsea
# 252      NaN   Newcastle Utd             1  Matchweek 21    Manchester City
#
#          opponent_y result_y         new_team_y
# 36      Bournemouth      NaN          Liverpool
# 54        Brentford      NaN  Nottingham Forest
# 126  Crystal Palace      NaN            Arsenal
# 162          Fulham      NaN            Chelsea
# 252   Newcastle Utd      NaN    Manchester City
