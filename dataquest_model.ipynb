# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
matches = pd.read_csv("./data/matches2024.csv", encoding='utf-8')

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  cmp%.1  cmp%.2  cmp%.3   ppa crspa  prgp   sca  gca  \
# 0        Chelsea  ...    89.0    82.2    46.7   8.0   2.0  34.0  24.0  2.0
# 1    Bournemouth  ...    87.9    92.0    60.9  10.0   0.0  40.0  40.0  4.0
# 2  Newcastle Utd  ...    92.1    87.1    41.8   6.0   0.0  26.0  16.0  3.0
# 3    Aston Villa  ...    95.3    93.3    64.3   9.0   1.0  41.0  32.0  2.0
# 4         Wolves  ...    92.3    87.7    64.8  13.0   4.0  73.0  30.0  4.0
#
#   season       team
# 0   2024  Liverpool
# 1   2024  Liverpool
# 2   2024  Liverpool
# 3   2024  Liverpool
# 4   2024  Liverpool
#
# [5 rows x 39 columns]

# %%
print(matches.shape)
# Out:
# (760, 39)

# %%
matches["team"].value_counts()
# Out:
# team
# Liverpool                   38
# Aston Villa                 38
# Burnley                     38
# Luton Town                  38
# Everton                     38
# Brentford                   38
# Nottingham Forest           38
# Crystal Palace              38
# Fulham                      38
# Bournemouth                 38
# Wolverhampton Wanderers     38
# Chelsea                     38
# Newcastle United            38
# Manchester United           38
# Brighton and Hove Albion    38
# West Ham United             38
# Tottenham Hotspur           38
# Arsenal                     38
# Manchester City             38
# Sheffield United            38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# 5   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      W  3.0
# 6   2023-09-30  17:30  Premier League   Matchweek 7  Sat  Away      L  1.0
# 7   2023-10-08  14:00  Premier League   Matchweek 8  Sun  Away      D  2.0
# 8   2023-10-21  12:30  Premier League   Matchweek 9  Sat  Home      W  2.0
# 9   2023-10-29  14:00  Premier League  Matchweek 10  Sun  Home      W  3.0
# 10  2023-11-05  16:30  Premier League  Matchweek 11  Sun  Away      D  1.0
# 11  2023-11-12  14:00  Premier League  Matchweek 12  Sun  Home      W  3.0
# 12  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Away      D  1.0
# 13  2023-12-03  14:00  Premier League  Matchweek 14  Sun  Home      W  4.0
# 14  2023-12-06  19:30  Premier League  Matchweek 15  Wed  Away      W  2.0
# 15  2023-12-09  12:30  Premier League  Matchweek 16  Sat  Away      W  2.0
# 16  2023-12-17  16:30  Premier League  Matchweek 17  Sun  Home      D  0.0
# 17  2023-12-23  17:30  Premier League  Matchweek 18  Sat  Home      D  1.0
# 18  2023-12-26  17:30  Premier League  Matchweek 19  Tue  Away      W  2.0
# 19  2024-01-01  20:00  Premier League  Matchweek 20  Mon  Home      W  4.0
# 20  2024-01-21  16:30  Premier League  Matchweek 21  Sun  Away    NaN  NaN
# 21  2024-01-31  20:15  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 22  2024-02-04  16:30  Premier League  Matchweek 23  Sun  Away    NaN  NaN
# 23  2024-02-10  15:00  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 24  2024-02-17  12:30  Premier League  Matchweek 25  Sat  Away    NaN  NaN
# 25  2024-02-24  15:00  Premier League  Matchweek 26  Sat  Home    NaN  NaN
# 26  2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away    NaN  NaN
# 27  2024-03-09    NaN  Premier League  Matchweek 28  Sat  Home    NaN  NaN
# 28  2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 29  2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 30  2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 31  2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 32  2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 33  2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 34  2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 35  2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 36  2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 37  2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#      ga         opponent  ...  cmp%.1  cmp%.2  cmp%.3   ppa crspa  prgp   sca  \
# 0   1.0          Chelsea  ...    89.0    82.2    46.7   8.0   2.0  34.0  24.0
# 1   1.0      Bournemouth  ...    87.9    92.0    60.9  10.0   0.0  40.0  40.0
# 2   1.0    Newcastle Utd  ...    92.1    87.1    41.8   6.0   0.0  26.0  16.0
# 3   0.0      Aston Villa  ...    95.3    93.3    64.3   9.0   1.0  41.0  32.0
# 4   1.0           Wolves  ...    92.3    87.7    64.8  13.0   4.0  73.0  30.0
# 5   1.0         West Ham  ...    92.0    91.6    65.6  10.0   0.0  72.0  41.0
# 6   2.0        Tottenham  ...    92.9    83.5    57.3   7.0   2.0  25.0  22.0
# 7   2.0         Brighton  ...    91.3    91.4    56.7  15.0   2.0  42.0  28.0
# 8   0.0          Everton  ...    92.1    90.1    55.6  14.0   1.0  64.0  45.0
# 9   0.0  Nott'ham Forest  ...    91.1    90.2    77.0  11.0   2.0  83.0  35.0
# 10  1.0       Luton Town  ...    87.6    89.7    70.8  20.0   5.0  82.0  44.0
# 11  0.0        Brentford  ...    85.9    83.4    62.2  12.0   1.0  50.0  30.0
# 12  1.0  Manchester City  ...    87.5    87.9    54.0   8.0   1.0  33.0  13.0
# 13  3.0           Fulham  ...    90.0    81.8    62.7  15.0   0.0  71.0  40.0
# 14  0.0    Sheffield Utd  ...    89.3    85.9    51.3  14.0   4.0  51.0  26.0
# 15  1.0   Crystal Palace  ...    93.4    88.8    56.8  15.0   1.0  65.0  23.0
# 16  0.0   Manchester Utd  ...    89.6    86.8    59.1  15.0   2.0  72.0  64.0
# 17  1.0          Arsenal  ...    83.8    86.0    47.1   8.0   1.0  42.0  24.0
# 18  0.0          Burnley  ...    87.8    89.3    63.1  18.0   2.0  54.0  32.0
# 19  2.0    Newcastle Utd  ...    93.2    85.3    58.5  16.0   6.0  58.0  58.0
# 20  NaN      Bournemouth  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 21  NaN          Chelsea  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 22  NaN          Arsenal  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 23  NaN          Burnley  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 24  NaN        Brentford  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 25  NaN       Luton Town  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 26  NaN  Nott'ham Forest  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 27  NaN  Manchester City  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 28  NaN          Everton  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 29  NaN         Brighton  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 30  NaN    Sheffield Utd  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 31  NaN   Manchester Utd  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 32  NaN   Crystal Palace  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 33  NaN           Fulham  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 34  NaN         West Ham  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 35  NaN        Tottenham  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 36  NaN      Aston Villa  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
# 37  NaN           Wolves  ...     NaN     NaN     NaN   NaN   NaN   NaN   NaN
#
#     gca season       team
# 0   2.0   2024  Liverpool
# 1   4.0   2024  Liverpool
# 2   3.0   2024  Liverpool
# 3   2.0   2024  Liverpool
# 4   4.0   2024  Liverpool
# 5   5.0   2024  Liverpool
# 6   2.0   2024  Liverpool
# 7   4.0   2024  Liverpool
# 8   3.0   2024  Liverpool
# 9   4.0   2024  Liverpool
# 10  2.0   2024  Liverpool
# 11  6.0   2024  Liverpool
# 12  2.0   2024  Liverpool
# 13  3.0   2024  Liverpool
# 14  2.0   2024  Liverpool
# 15  4.0   2024  Liverpool
# 16  0.0   2024  Liverpool
# 17  2.0   2024  Liverpool
# 18  4.0   2024  Liverpool
# 19  8.0   2024  Liverpool
# 20  NaN   2024  Liverpool
# 21  NaN   2024  Liverpool
# 22  NaN   2024  Liverpool
# 23  NaN   2024  Liverpool
# 24  NaN   2024  Liverpool
# 25  NaN   2024  Liverpool
# 26  NaN   2024  Liverpool
# 27  NaN   2024  Liverpool
# 28  NaN   2024  Liverpool
# 29  NaN   2024  Liverpool
# 30  NaN   2024  Liverpool
# 31  NaN   2024  Liverpool
# 32  NaN   2024  Liverpool
# 33  NaN   2024  Liverpool
# 34  NaN   2024  Liverpool
# 35  NaN   2024  Liverpool
# 36  NaN   2024  Liverpool
# 37  NaN   2024  Liverpool
#
# [38 rows x 39 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     20
# Matchweek 29    20
# Matchweek 22    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 28    20
# Matchweek 30    20
# Matchweek 2     20
# Matchweek 31    20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 21    20
# Matchweek 20    20
# Matchweek 19    20
# Matchweek 18    20
# Matchweek 3     20
# Matchweek 4     20
# Matchweek 5     20
# Matchweek 6     20
# Matchweek 7     20
# Matchweek 8     20
# Matchweek 9     20
# Matchweek 10    20
# Matchweek 11    20
# Matchweek 12    20
# Matchweek 13    20
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# sota            float64
# save%           float64
# pksv            float64
# cmp%            float64
# cmp%.1          float64
# cmp%.2          float64
# cmp%.3          float64
# ppa             float64
# crspa           float64
# prgp            float64
# sca             float64
# gca             float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# sota                   float64
# save%                  float64
# pksv                   float64
# cmp%                   float64
# cmp%.1                 float64
# cmp%.2                 float64
# cmp%.3                 float64
# ppa                    float64
# crspa                  float64
# prgp                   float64
# sca                    float64
# gca                    float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 755 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Home    NaN  NaN
# 756 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 757 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 758 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 759 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...  crspa  prgp   sca  gca season  \
# 0    1.0          Chelsea  ...    2.0  34.0  24.0  2.0   2024
# 1    1.0      Bournemouth  ...    0.0  40.0  40.0  4.0   2024
# 2    1.0    Newcastle Utd  ...    0.0  26.0  16.0  3.0   2024
# 3    0.0      Aston Villa  ...    1.0  41.0  32.0  2.0   2024
# 4    1.0           Wolves  ...    4.0  73.0  30.0  4.0   2024
# ..   ...              ...  ...    ...   ...   ...  ...    ...
# 755  NaN          Burnley  ...    NaN   NaN   NaN  NaN   2024
# 756  NaN    Newcastle Utd  ...    NaN   NaN   NaN  NaN   2024
# 757  NaN  Nott'ham Forest  ...    NaN   NaN   NaN  NaN   2024
# 758  NaN          Everton  ...    NaN   NaN   NaN  NaN   2024
# 759  NaN        Tottenham  ...    NaN   NaN   NaN  NaN   2024
#
#                  team target venue_code opp_code  day_code
# 0           Liverpool      0          0        6         6
# 1           Liverpool      1          1        2         5
# 2           Liverpool      1          0       14         6
# 3           Liverpool      1          1        1         6
# 4           Liverpool      1          0       19         5
# ..                ...    ...        ...      ...       ...
# 755  Sheffield United      0          1        5         5
# 756  Sheffield United      0          0       14         5
# 757  Sheffield United      0          1       15         5
# 758  Sheffield United      0          0        8         5
# 759  Sheffield United      0          1       17         6
#
# [760 rows x 43 columns]

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2023-12-10']
test = matches[(matches["date"] >= '2023-12-10') & (matches["date"] <= '2024-01-02')]
test.dropna(subset=['result'], inplace=True)
predictors =["venue_code", "opp_code", "day_code"]
rf.fit(train[predictors], train["target"])
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\1327913508.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.dropna(subset=['result'], inplace=True)
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6547619047619048

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           36  12
# 1           17  19

# %%
precision_score(test["target"], preds, average='micro')
# Out:
# 0.6547619047619048

# %%
groupsed_matches = matches.groupby("team")

# %%
group = groupsed_matches.get_group("Manchester City")
group
# Out:
#           date   time            comp         round  day venue result   gf  \
# 76  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 77  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 78  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 79  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 80  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 81  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 82  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 83  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 84  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 85  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 86  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 87  2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 88  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 89  2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 90  2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 91  2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 92  2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 93  2023-12-23    NaN  Premier League  Matchweek 18  Sat  Home    NaN  NaN
# 94  2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 95  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 96  2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away    NaN  NaN
# 97  2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 98  2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away    NaN  NaN
# 99  2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 100 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home    NaN  NaN
# 101 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away    NaN  NaN
# 102 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Home    NaN  NaN
# 103 2024-03-09    NaN  Premier League  Matchweek 28  Sat  Away    NaN  NaN
# 104 2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 105 2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 106 2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 107 2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 108 2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 109 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 110 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 111 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 112 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 113 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...  crspa  prgp   sca   gca season  \
# 76   0.0          Burnley  ...    2.0  28.0  29.0   5.0   2024
# 77   0.0    Newcastle Utd  ...    0.0  42.0  27.0   2.0   2024
# 78   1.0    Sheffield Utd  ...    3.0  75.0  58.0   4.0   2024
# 79   1.0           Fulham  ...    1.0  38.0  13.0   9.0   2024
# 80   1.0         West Ham  ...    3.0  75.0  55.0   6.0   2024
# 81   0.0  Nott'ham Forest  ...    0.0  31.0  14.0   4.0   2024
# 82   2.0           Wolves  ...    2.0  68.0  41.0   2.0   2024
# 83   1.0          Arsenal  ...    0.0  28.0   7.0   0.0   2024
# 84   1.0         Brighton  ...    0.0  38.0  17.0   2.0   2024
# 85   0.0   Manchester Utd  ...    2.0  59.0  40.0   6.0   2024
# 86   1.0      Bournemouth  ...    3.0  65.0  40.0  11.0   2024
# 87   4.0          Chelsea  ...    3.0  61.0  29.0   7.0   2024
# 88   1.0        Liverpool  ...    2.0  58.0  30.0   2.0   2024
# 89   3.0        Tottenham  ...    1.0  33.0  32.0   4.0   2024
# 90   1.0      Aston Villa  ...    1.0  29.0   4.0   0.0   2024
# 91   1.0       Luton Town  ...    2.0  35.0  30.0   4.0   2024
# 92   2.0   Crystal Palace  ...    4.0  64.0  36.0   2.0   2024
# 93   NaN        Brentford  ...    NaN   NaN   NaN   NaN   2024
# 94   1.0          Everton  ...    3.0  47.0  38.0   3.0   2024
# 95   0.0    Sheffield Utd  ...    2.0  63.0  31.0   4.0   2024
# 96   NaN    Newcastle Utd  ...    NaN   NaN   NaN   NaN   2024
# 97   NaN          Burnley  ...    NaN   NaN   NaN   NaN   2024
# 98   NaN        Brentford  ...    NaN   NaN   NaN   NaN   2024
# 99   NaN          Everton  ...    NaN   NaN   NaN   NaN   2024
# 100  NaN          Chelsea  ...    NaN   NaN   NaN   NaN   2024
# 101  NaN      Bournemouth  ...    NaN   NaN   NaN   NaN   2024
# 102  NaN   Manchester Utd  ...    NaN   NaN   NaN   NaN   2024
# 103  NaN        Liverpool  ...    NaN   NaN   NaN   NaN   2024
# 104  NaN         Brighton  ...    NaN   NaN   NaN   NaN   2024
# 105  NaN          Arsenal  ...    NaN   NaN   NaN   NaN   2024
# 106  NaN      Aston Villa  ...    NaN   NaN   NaN   NaN   2024
# 107  NaN   Crystal Palace  ...    NaN   NaN   NaN   NaN   2024
# 108  NaN       Luton Town  ...    NaN   NaN   NaN   NaN   2024
# 109  NaN        Tottenham  ...    NaN   NaN   NaN   NaN   2024
# 110  NaN  Nott'ham Forest  ...    NaN   NaN   NaN   NaN   2024
# 111  NaN           Wolves  ...    NaN   NaN   NaN   NaN   2024
# 112  NaN           Fulham  ...    NaN   NaN   NaN   NaN   2024
# 113  NaN         West Ham  ...    NaN   NaN   NaN   NaN   2024
#
#                 team target venue_code opp_code  day_code
# 76   Manchester City      1          0        5         4
# 77   Manchester City      1          1       14         5
# 78   Manchester City      1          0       16         6
# 79   Manchester City      1          1        9         5
# 80   Manchester City      1          0       18         5
# 81   Manchester City      1          1       15         5
# 82   Manchester City      0          0       19         5
# 83   Manchester City      0          0        0         6
# 84   Manchester City      1          1        4         5
# 85   Manchester City      1          0       13         6
# 86   Manchester City      1          1        2         5
# 87   Manchester City      0          0        6         6
# 88   Manchester City      0          1       10         5
# 89   Manchester City      0          1       17         6
# 90   Manchester City      0          0        1         2
# 91   Manchester City      1          0       11         6
# 92   Manchester City      0          1        7         5
# 93   Manchester City      0          1        3         5
# 94   Manchester City      1          0        8         2
# 95   Manchester City      1          1       16         5
# 96   Manchester City      0          0       14         5
# 97   Manchester City      0          1        5         2
# 98   Manchester City      0          0        3         0
# 99   Manchester City      0          1        8         5
# 100  Manchester City      0          1        6         5
# 101  Manchester City      0          0        2         5
# 102  Manchester City      0          1       13         5
# 103  Manchester City      0          0       10         5
# 104  Manchester City      0          0        4         5
# 105  Manchester City      0          1        0         5
# 106  Manchester City      0          1        1         2
# 107  Manchester City      0          0        7         5
# 108  Manchester City      0          1       11         5
# 109  Manchester City      0          0       17         5
# 110  Manchester City      0          0       15         5
# 111  Manchester City      0          1       19         5
# 112  Manchester City      0          0        9         5
# 113  Manchester City      0          1       18         6
#
# [38 rows x 43 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
    group[new_cols] = rolling_stats
    nan_index = group[group[new_cols].isna()].index
    for idx in nan_index:
        for col in new_cols:  # Ignora a coluna 'Rodada'
            group.at[idx, f'{col}'] = group.loc[idx - 3 + 1:idx, col].mean()
    return group

# %%
group.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'sota', 'save%', 'pksv', 'cmp%', 'cmp%.1', 'cmp%.2', 'cmp%.3',
#        'ppa', 'crspa', 'prgp', 'sca', 'gca', 'season', 'team', 'target',
#        'venue_code', 'opp_code', 'day_code'],
#       dtype='object')

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt","sota", "save%", "pksv", "cmp%", "ppa", "crspa", "prgp","sca", "gca"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling',
#  'sota_rolling',
#  'save%_rolling',
#  'pksv_rolling',
#  'cmp%_rolling',
#  'ppa_rolling',
#  'crspa_rolling',
#  'prgp_rolling',
#  'sca_rolling',
#  'gca_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
#           date   time            comp         round  day venue result   gf  \
# 76  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 77  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 78  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 79  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 80  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 81  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 82  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 83  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 84  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 85  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 86  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 87  2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 88  2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 89  2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 90  2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 91  2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 92  2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 93  2023-12-23    NaN  Premier League  Matchweek 18  Sat  Home    NaN  NaN
# 94  2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 95  2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 96  2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away    NaN  NaN
# 97  2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home    NaN  NaN
# 98  2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away    NaN  NaN
# 99  2024-02-10  12:30  Premier League  Matchweek 24  Sat  Home    NaN  NaN
# 100 2024-02-17  17:30  Premier League  Matchweek 25  Sat  Home    NaN  NaN
# 101 2024-02-24  17:30  Premier League  Matchweek 26  Sat  Away    NaN  NaN
# 102 2024-03-02  15:00  Premier League  Matchweek 27  Sat  Home    NaN  NaN
# 103 2024-03-09    NaN  Premier League  Matchweek 28  Sat  Away    NaN  NaN
# 104 2024-03-16    NaN  Premier League  Matchweek 29  Sat  Away    NaN  NaN
# 105 2024-03-30    NaN  Premier League  Matchweek 30  Sat  Home    NaN  NaN
# 106 2024-04-03    NaN  Premier League  Matchweek 31  Wed  Home    NaN  NaN
# 107 2024-04-06    NaN  Premier League  Matchweek 32  Sat  Away    NaN  NaN
# 108 2024-04-13    NaN  Premier League  Matchweek 33  Sat  Home    NaN  NaN
# 109 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Away    NaN  NaN
# 110 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Away    NaN  NaN
# 111 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Home    NaN  NaN
# 112 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Away    NaN  NaN
# 113 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Home    NaN  NaN
#
#       ga         opponent  ...  pkatt_rolling  sota_rolling  save%_rolling  \
# 76   0.0          Burnley  ...       0.333333      1.000000      66.666667
# 77   0.0    Newcastle Utd  ...       0.333333      1.000000      66.666667
# 78   1.0    Sheffield Utd  ...       0.333333      1.000000      66.666667
# 79   1.0           Fulham  ...       0.333333      1.000000      66.666667
# 80   1.0         West Ham  ...       0.333333      1.000000      66.666667
# 81   0.0  Nott'ham Forest  ...       0.444444      1.333333      63.888889
# 82   2.0           Wolves  ...       0.481481      1.666667      59.262963
# 83   1.0          Arsenal  ...       0.419753      2.111111      67.906173
# 84   1.0         Brighton  ...       0.300412      2.037037      49.800823
# 85   0.0   Manchester Utd  ...       0.240055      2.049383      44.791221
# 86   1.0      Bournemouth  ...       0.180155      2.028807      33.386237
# 87   4.0          Chelsea  ...       0.251181      2.248285      50.136930
# 88   1.0        Liverpool  ...       0.254890      2.203475      46.363278
# 89   3.0        Tottenham  ...       0.390913      2.928365      50.688958
# 90   1.0      Aston Villa  ...       0.326379      3.155058      47.172968
# 91   1.0       Luton Town  ...       0.350208      3.805585      50.220642
# 92   2.0   Crystal Palace  ...       0.225529      3.875770      52.175648
# 93   NaN        Brentford  ...       0.191912      4.004896      51.987652
# 94   1.0          Everton  ...       0.139147      3.849111      55.354433
# 95   0.0    Sheffield Utd  ...       0.165530      3.927003      53.671043
# 96   NaN    Newcastle Utd  ...       0.152338      3.888057      54.512738
# 97   NaN          Burnley  ...       0.158934      3.907530      54.091890
# 98   NaN        Brentford  ...       0.155636      3.897794      54.302314
# 99   NaN          Everton  ...       0.157285      3.902662      54.197102
# 100  NaN          Chelsea  ...       0.156461      3.900228      54.249708
# 101  NaN      Bournemouth  ...       0.156873      3.901445      54.223405
# 102  NaN   Manchester Utd  ...       0.156667      3.900836      54.236557
# 103  NaN        Liverpool  ...       0.156770      3.901141      54.229981
# 104  NaN         Brighton  ...       0.156718      3.900989      54.233269
# 105  NaN          Arsenal  ...       0.156744      3.901065      54.231625
# 106  NaN      Aston Villa  ...       0.156731      3.901027      54.232447
# 107  NaN   Crystal Palace  ...       0.156738      3.901046      54.232036
# 108  NaN       Luton Town  ...       0.156734      3.901036      54.232241
# 109  NaN        Tottenham  ...       0.156736      3.901041      54.232139
# 110  NaN  Nott'ham Forest  ...       0.156735      3.901038      54.232190
# 111  NaN           Wolves  ...       0.156736      3.901040      54.232164
# 112  NaN           Fulham  ...       0.156735      3.901039      54.232177
# 113  NaN         West Ham  ...       0.156736      3.901039      54.232171
#
#      pksv_rolling cmp%_rolling ppa_rolling crspa_rolling prgp_rolling  \
# 76            0.0    88.733333   13.333333      1.666667    48.333333
# 77            0.0    88.733333   13.333333      1.666667    48.333333
# 78            0.0    88.733333   13.333333      1.666667    48.333333
# 79            0.0    88.733333   13.333333      1.666667    48.333333
# 80            0.0    88.733333   13.333333      1.666667    48.333333
# 81            0.0    88.777778   13.111111      1.555556    49.444444
# 82            0.0    89.014815   14.259259      1.851852    53.481481
# 83            0.0    88.930864   12.567901      1.580247    50.308642
# 84            0.0    88.704115   13.053498      1.699588    53.930041
# 85            0.0    88.011660   11.207133      1.315501    48.857339
# 86            0.0    87.771925   10.864655      1.227252    49.151349
# 87            0.0    87.550084   10.579485      1.069806    46.558451
# 88            0.0    88.085114   11.481380      1.321242    49.903267
# 89            0.0    88.167288   12.909177      1.685905    52.709462
# 90            0.0    88.484134   12.796852      1.891271    54.648687
# 91            0.0    87.917141   12.457565      1.859059    52.674939
# 92            0.0    87.589314   11.529250      1.694554    49.107875
# 93            0.0    86.957707   11.106716      1.628982    44.705382
# 94            0.0    87.226785   10.989767      1.885623    45.493308
# 95            0.0    87.092246   11.048242      1.757303    45.099345
# 96            0.0    87.159515   11.019004      1.821463    45.296327
# 97            0.0    87.125881   11.033623      1.789383    45.197836
# 98            0.0    87.142698   11.026313      1.805423    45.247081
# 99            0.0    87.134289   11.029968      1.797403    45.222459
# 100           0.0    87.138494   11.028141      1.801413    45.234770
# 101           0.0    87.136391   11.029054      1.799408    45.228614
# 102           0.0    87.137443   11.028598      1.800410    45.231692
# 103           0.0    87.136917   11.028826      1.799909    45.230153
# 104           0.0    87.137180   11.028712      1.800160    45.230923
# 105           0.0    87.137048   11.028769      1.800034    45.230538
# 106           0.0    87.137114   11.028740      1.800097    45.230730
# 107           0.0    87.137081   11.028755      1.800066    45.230634
# 108           0.0    87.137098   11.028748      1.800081    45.230682
# 109           0.0    87.137089   11.028751      1.800074    45.230658
# 110           0.0    87.137094   11.028749      1.800078    45.230670
# 111           0.0    87.137092   11.028750      1.800076    45.230664
# 112           0.0    87.137093   11.028750      1.800077    45.230667
# 113           0.0    87.137092   11.028750      1.800076    45.230666
#
#     sca_rolling  gca_rolling
# 76    38.000000     3.666667
# 77    38.000000     3.666667
# 78    38.000000     3.666667
# 79    38.000000     3.666667
# 80    38.000000     3.666667
# 81    36.222222     4.111111
# 82    38.740741     4.703704
# 83    34.098765     5.049383
# 84    36.502058     4.584362
# 85    30.422497     3.877915
# 86    29.530407     3.265203
# 87    27.095412     3.269928
# 88    29.653051     4.289488
# 89    31.027265     5.186472
# 90    31.226772     5.380876
# 91    30.862457     4.966894
# 92    28.029743     4.115923
# 93    26.964067     3.916495
# 94    26.109048     3.344139
# 95    26.536557     3.630317
# 96    26.322802     3.487228
# 97    26.429680     3.558772
# 98    26.376241     3.523000
# 99    26.402960     3.540886
# 100   26.389601     3.531943
# 101   26.396281     3.536415
# 102   26.392941     3.534179
# 103   26.394611     3.535297
# 104   26.393776     3.534738
# 105   26.394193     3.535018
# 106   26.393984     3.534878
# 107   26.394089     3.534948
# 108   26.394037     3.534913
# 109   26.394063     3.534930
# 110   26.394050     3.534921
# 111   26.394056     3.534926
# 112   26.394053     3.534924
# 113   26.394055     3.534925
#
# [38 rows x 60 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
# C:\Users\Carlos\AppData\Local\Temp\ipykernel_15116\3831888422.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rolling_stats = group[cols].shift(1).rolling(3, closed='left').mean().fillna(method='bfill')
#                                   date   time            comp         round  \
# team
# Arsenal                 114 2023-08-12  12:30  Premier League   Matchweek 1
#                         115 2023-08-21  20:00  Premier League   Matchweek 2
#                         116 2023-08-26  15:00  Premier League   Matchweek 3
#                         117 2023-09-03  16:30  Premier League   Matchweek 4
#                         118 2023-09-17  16:30  Premier League   Matchweek 5
# ...                                ...    ...             ...           ...
# Wolverhampton Wanderers 413 2024-04-20    NaN  Premier League  Matchweek 34
#                         414 2024-04-27    NaN  Premier League  Matchweek 35
#                         415 2024-05-04    NaN  Premier League  Matchweek 36
#                         416 2024-05-11    NaN  Premier League  Matchweek 37
#                         417 2024-05-19    NaN  Premier League  Matchweek 38
#
#                              day venue result   gf   ga         opponent  ...  \
# team                                                                      ...
# Arsenal                 114  Sat  Home      W  2.0  1.0  Nott'ham Forest  ...
#                         115  Mon  Away      W  1.0  0.0   Crystal Palace  ...
#                         116  Sat  Home      D  2.0  2.0           Fulham  ...
#                         117  Sun  Home      W  3.0  1.0   Manchester Utd  ...
#                         118  Sun  Away      W  1.0  0.0          Everton  ...
# ...                          ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 413  Sat  Home    NaN  NaN  NaN          Arsenal  ...
#                         414  Sat  Home    NaN  NaN  NaN       Luton Town  ...
#                         415  Sat  Away    NaN  NaN  NaN  Manchester City  ...
#                         416  Sat  Home    NaN  NaN  NaN   Crystal Palace  ...
#                         417  Sun  Away    NaN  NaN  NaN        Liverpool  ...
#
#                              pkatt_rolling  sota_rolling  save%_rolling  \
# team
# Arsenal                 114       0.666667      2.333333      61.100000
#                         115       0.666667      2.333333      61.100000
#                         116       0.666667      2.333333      61.100000
#                         117       0.666667      2.333333      61.100000
#                         118       0.666667      2.333333      61.100000
# ...                                    ...           ...            ...
# Wolverhampton Wanderers 413       0.049111      3.601458      62.786526
#                         414       0.049112      3.601512      62.786530
#                         415       0.049111      3.601485      62.786528
#                         416       0.049112      3.601499      62.786529
#                         417       0.049112      3.601492      62.786528
#
#                              pksv_rolling cmp%_rolling ppa_rolling  \
# team
# Arsenal                 114           0.0    86.100000   17.000000
#                         115           0.0    86.100000   17.000000
#                         116           0.0    86.100000   17.000000
#                         117           0.0    86.100000   17.000000
#                         118           0.0    86.100000   17.000000
# ...                                   ...          ...         ...
# Wolverhampton Wanderers 413           0.0    76.429324    6.749397
#                         414           0.0    76.429464    6.749283
#                         415           0.0    76.429394    6.749340
#                         416           0.0    76.429429    6.749311
#                         417           0.0    76.429412    6.749326
#
#                             crspa_rolling prgp_rolling sca_rolling  \
# team
# Arsenal                 114      2.333333    63.666667   30.000000
#                         115      2.333333    63.666667   30.000000
#                         116      2.333333    63.666667   30.000000
#                         117      2.333333    63.666667   30.000000
#                         118      2.333333    63.666667   30.000000
# ...                                   ...          ...         ...
# Wolverhampton Wanderers 413      1.576403    32.455151   19.215340
#                         414      1.576416    32.455174   19.215330
#                         415      1.576410    32.455162   19.215335
#                         416      1.576413    32.455168   19.215333
#                         417      1.576411    32.455165   19.215334
#
#                              gca_rolling
# team
# Arsenal                 114     3.000000
#                         115     3.000000
#                         116     3.000000
#                         117     3.000000
#                         118     3.000000
# ...                                  ...
# Wolverhampton Wanderers 413     2.996322
#                         414     2.996223
#                         415     2.996273
#                         416     2.996248
#                         417     2.996260
#
# [760 rows x 60 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2.0
# 1   2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1.0
# 2   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D  2.0
# 3   2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 755 2024-04-20    NaN  Premier League  Matchweek 34  Sat  Home    NaN  NaN
# 756 2024-04-27    NaN  Premier League  Matchweek 35  Sat  Home    NaN  NaN
# 757 2024-05-04    NaN  Premier League  Matchweek 36  Sat  Away    NaN  NaN
# 758 2024-05-11    NaN  Premier League  Matchweek 37  Sat  Home    NaN  NaN
# 759 2024-05-19    NaN  Premier League  Matchweek 38  Sun  Away    NaN  NaN
#
#       ga         opponent  ...  pkatt_rolling  sota_rolling  save%_rolling  \
# 0    1.0  Nott'ham Forest  ...       0.666667      2.333333      61.100000
# 1    0.0   Crystal Palace  ...       0.666667      2.333333      61.100000
# 2    2.0           Fulham  ...       0.666667      2.333333      61.100000
# 3    1.0   Manchester Utd  ...       0.666667      2.333333      61.100000
# 4    0.0          Everton  ...       0.666667      2.333333      61.100000
# ..   ...              ...  ...            ...           ...            ...
# 755  NaN          Arsenal  ...       0.049111      3.601458      62.786526
# 756  NaN       Luton Town  ...       0.049112      3.601512      62.786530
# 757  NaN  Manchester City  ...       0.049111      3.601485      62.786528
# 758  NaN   Crystal Palace  ...       0.049112      3.601499      62.786529
# 759  NaN        Liverpool  ...       0.049112      3.601492      62.786528
#
#      pksv_rolling cmp%_rolling ppa_rolling crspa_rolling prgp_rolling  \
# 0             0.0    86.100000   17.000000      2.333333    63.666667
# 1             0.0    86.100000   17.000000      2.333333    63.666667
# 2             0.0    86.100000   17.000000      2.333333    63.666667
# 3             0.0    86.100000   17.000000      2.333333    63.666667
# 4             0.0    86.100000   17.000000      2.333333    63.666667
# ..            ...          ...         ...           ...          ...
# 755           0.0    76.429324    6.749397      1.576403    32.455151
# 756           0.0    76.429464    6.749283      1.576416    32.455174
# 757           0.0    76.429394    6.749340      1.576410    32.455162
# 758           0.0    76.429429    6.749311      1.576413    32.455168
# 759           0.0    76.429412    6.749326      1.576411    32.455165
#
#     sca_rolling  gca_rolling
# 0     30.000000     3.000000
# 1     30.000000     3.000000
# 2     30.000000     3.000000
# 3     30.000000     3.000000
# 4     30.000000     3.000000
# ..          ...          ...
# 755   19.215340     2.996322
# 756   19.215330     2.996223
# 757   19.215335     2.996273
# 758   19.215333     2.996248
# 759   19.215334     2.996260
#
# [760 rows x 60 columns]

# %%
matches_rolling[matches_rolling["round"]=="Matchweek 21"]
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 20  2024-01-20  12:30  Premier League  Matchweek 21  Sat  Home    NaN NaN NaN
# 58  2024-01-14  14:00  Premier League  Matchweek 21  Sun  Away    NaN NaN NaN
# 96  2024-01-21  16:30  Premier League  Matchweek 21  Sun  Home    NaN NaN NaN
# 134 2024-01-20  17:30  Premier League  Matchweek 21  Sat  Home    NaN NaN NaN
# 172 2024-01-22  19:45  Premier League  Matchweek 21  Mon  Home    NaN NaN NaN
# 210 2024-01-15  19:45  Premier League  Matchweek 21  Mon  Home    NaN NaN NaN
# 248 2024-01-13  12:30  Premier League  Matchweek 21  Sat  Home    NaN NaN NaN
# 286 2024-01-20  12:30  Premier League  Matchweek 21  Sat  Away    NaN NaN NaN
# 324 2024-01-14  14:00  Premier League  Matchweek 21  Sun  Home    NaN NaN NaN
# 362 2024-01-13  12:30  Premier League  Matchweek 21  Sat  Away    NaN NaN NaN
# 400 2024-01-21  16:30  Premier League  Matchweek 21  Sun  Away    NaN NaN NaN
# 438 2024-01-15  19:45  Premier League  Matchweek 21  Mon  Away    NaN NaN NaN
# 476 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away    NaN NaN NaN
# 514 2024-01-14  16:30  Premier League  Matchweek 21  Sun  Home    NaN NaN NaN
# 552 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Home    NaN NaN NaN
# 590 2024-01-20  17:30  Premier League  Matchweek 21  Sat  Away    NaN NaN NaN
# 628 2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home    NaN NaN NaN
# 666 2024-01-14  16:30  Premier League  Matchweek 21  Sun  Away    NaN NaN NaN
# 704 2024-01-21  14:00  Premier League  Matchweek 21  Sun  Away    NaN NaN NaN
# 742 2024-01-22  19:45  Premier League  Matchweek 21  Mon  Away    NaN NaN NaN
#
#             opponent  ...  pkatt_rolling  sota_rolling  save%_rolling  \
# 20    Crystal Palace  ...       0.072353      2.490682      66.011274
# 58           Everton  ...       0.032970      3.818375      69.903500
# 96         Liverpool  ...       0.197531      4.318888      66.020986
# 134  Nott'ham Forest  ...       0.203830      4.459804      58.307496
# 172           Wolves  ...       0.285794      4.139571      65.073791
# 210       Luton Town  ...       0.059137      6.192272      74.797866
# 248           Fulham  ...       0.304208      5.151519      73.701223
# 286          Arsenal  ...       0.356856      4.804593      55.329068
# 324      Aston Villa  ...       0.000000      4.077516      83.664381
# 362          Chelsea  ...       0.118275      5.631851      64.125667
# 400      Bournemouth  ...       0.050539      2.386021      84.492135
# 438          Burnley  ...       0.011433      5.345155      68.893368
# 476    Newcastle Utd  ...       0.152338      3.888057      54.512738
# 514        Tottenham  ...       0.170917      4.984337      69.934782
# 552  Manchester City  ...       0.156163      5.298540      77.346382
# 590        Brentford  ...       0.059137      5.178001      62.659705
# 628         West Ham  ...       0.054606      5.884789      65.370633
# 666   Manchester Utd  ...       0.115226      4.658690      74.307308
# 704    Sheffield Utd  ...       0.116889      4.870265      79.235341
# 742         Brighton  ...       0.059137      3.896441      62.807369
#
#      pksv_rolling cmp%_rolling ppa_rolling crspa_rolling prgp_rolling  \
# 20       0.111111    83.883800   14.657415      2.356871    60.852461
# 58       0.000000    81.604878   10.509735      2.104891    45.829425
# 96       0.005777    77.733437   11.564011      3.675937    40.400660
# 134      0.000000    73.706650    7.083791      2.186542    29.813071
# 172      0.000000    87.080294   11.705380      1.975459    53.226229
# 210      0.000000    75.977513    5.517715      1.026467    34.010768
# 248      0.104252    85.889101    9.466241      0.738742    45.259129
# 286      0.000000    74.481212    6.207659      1.355616    25.094539
# 324      0.000000    69.722760    8.584369      2.526593    29.068114
# 362      0.000000    80.778970    9.666423      2.321402    42.130378
# 400      0.000000    81.591739   13.378450      1.742410    57.799145
# 438      0.000000    71.974990    6.079330      2.434137    27.502441
# 476      0.000000    87.159515   11.019004      1.821463    45.296327
# 514      0.000000    77.859104    8.403590      1.257947    39.002293
# 552      0.000000    83.254798   14.347936      3.252927    53.964178
# 590      0.000000    71.586773    6.093898      2.116107    29.062610
# 628      0.000000    64.677695    4.949135      0.815023    20.044082
# 666      0.000000    85.315445   13.502318      2.058911    54.370053
# 704      0.005777    75.585012    5.600003      1.563844    33.453797
# 742      0.000000    77.193766    6.129027      1.643895    32.580546
#
#     sca_rolling  gca_rolling
# 20    34.960321     2.654004
# 58    24.117688     3.205992
# 96    30.104157     3.921854
# 134   20.748442     1.436566
# 172   26.761793     2.813232
# 210   18.999980     1.944300
# 248   24.190603     3.070845
# 286   18.095084     2.006552
# 324   21.655633     1.862437
# 362   20.950557     3.038305
# 400   35.378376     2.471030
# 438   19.848469     2.122940
# 476   26.322802     3.487228
# 514   23.005885     1.516097
# 552   30.454273     2.491198
# 590   18.836230     2.039426
# 628   13.602253     0.844668
# 666   28.340077     3.156649
# 704   18.639082     3.111418
# 742   19.163397     2.459193
#
# [20 rows x 60 columns]

# %%
def make_predictions(data, predictors):
    rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
    #train = data[data["date"]<='2024-01-02']
    #test = data[data["date"] > '2024-01-02']
    train = data[data["date"] < '2023-12-10']
    test = data[(data["date"] >= '2023-12-10') & (data["date"] <= '2024-01-02')]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index=test.index)
    predicao = pd.DataFrame(dict(prediction=preds), index=test.index)
    error = precision_score(test["target"], preds, average='micro')
    return combined, error, predicao

# %%
combined, error, predicao = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5795454545454546

# %%
predicao
# Out:
#      prediction
# 16            1
# 17            1
# 18            1
# 19            0
# 54            0
# ..          ...
# 703           0
# 738           0
# 739           0
# 740           0
# 741           0
#
# [88 rows x 1 columns]

# %%
predicao = predicao.merge(matches_rolling[["date", "round", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
predicao[predicao["round"] == "Matchweek 21"].sort_values("date")
# Out:
# Empty DataFrame
# Columns: [prediction, date, round, team, opponent, result]
# Index: []

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values={
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Totteham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
predicao["new_team"] = predicao["team"].map(mapping)

# %%
merged = predicao.merge(predicao, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged.sort_values('date')
# Out:
#     prediction_x       date       round_x                    team_x  \
# 66             0 2023-12-10  Matchweek 16           West Ham United
# 52             0 2023-12-10  Matchweek 16           Manchester City
# 24             0 2023-12-10  Matchweek 16                   Chelsea
# 47             0 2023-12-10  Matchweek 16                Luton Town
# 61             0 2023-12-10  Matchweek 16          Newcastle United
# ..           ...        ...           ...                       ...
# 3              0 2023-12-31  Matchweek 20                   Arsenal
# 46             1 2024-01-01  Matchweek 20                 Liverpool
# 65             1 2024-01-01  Matchweek 20          Newcastle United
# 19             0 2024-01-02  Matchweek 20  Brighton and Hove Albion
# 70             0 2024-01-02  Matchweek 20           West Ham United
#
#          opponent_x result_x       new_team_x  prediction_y       round_y  \
# 66           Fulham        L         West Ham             0  Matchweek 16
# 52       Luton Town        W  Manchester City             0  Matchweek 16
# 24          Everton        L          Chelsea             1  Matchweek 16
# 47  Manchester City        L       Luton Town             0  Matchweek 16
# 61        Tottenham        L    Newcastle Utd             0  Matchweek 16
# ..              ...      ...              ...           ...           ...
# 3            Fulham        L          Arsenal             0  Matchweek 20
# 46    Newcastle Utd        W        Liverpool             1  Matchweek 20
# 65        Liverpool        L    Newcastle Utd             1  Matchweek 20
# 19         West Ham        D         Brighton             0  Matchweek 20
# 70         Brighton        D         West Ham             0  Matchweek 20
#
#                       team_y       opponent_y result_y       new_team_y
# 66                    Fulham         West Ham        W           Fulham
# 52                Luton Town  Manchester City        L       Luton Town
# 24                   Everton          Chelsea        W          Everton
# 47           Manchester City       Luton Town        W  Manchester City
# 61         Tottenham Hotspur    Newcastle Utd        W         Totteham
# ..                       ...              ...      ...              ...
# 3                     Fulham          Arsenal        W           Fulham
# 46          Newcastle United        Liverpool        L    Newcastle Utd
# 65                 Liverpool    Newcastle Utd        W        Liverpool
# 19           West Ham United         Brighton        D         West Ham
# 70  Brighton and Hove Albion         West Ham        D         Brighton
#
# [75 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] ==0) & (merged["round_x"] == "Matchweek 21")]
# Out:
#      prediction_x       date       round_x                    team_x  \
# 0               1 2024-01-20  Matchweek 21                   Arsenal
# 72              1 2024-01-22  Matchweek 21  Brighton and Hove Albion
# 180             1 2024-01-21  Matchweek 21                 Liverpool
#
#          opponent_x result_x new_team_x  prediction_y       round_y  \
# 0    Crystal Palace      NaN    Arsenal             0  Matchweek 21
# 72           Wolves      NaN   Brighton             0  Matchweek 21
# 180     Bournemouth      NaN  Liverpool             0  Matchweek 21
#
#                       team_y opponent_y result_y      new_team_y
# 0             Crystal Palace    Arsenal      NaN  Crystal Palace
# 72   Wolverhampton Wanderers   Brighton      NaN          Wolves
# 180              Bournemouth  Liverpool      NaN     Bournemouth

# %%
merged[(merged["prediction_y"] == 1) & (merged["prediction_x"] ==0) & (merged["round_x"] == "Matchweek 21")]
# Out:
#      prediction_x       date       round_x                   team_x  \
# 36              0 2024-01-21  Matchweek 21              Bournemouth
# 54              0 2024-01-20  Matchweek 21                Brentford
# 126             0 2024-01-20  Matchweek 21           Crystal Palace
# 288             0 2024-01-22  Matchweek 21  Wolverhampton Wanderers
#
#           opponent_x result_x      new_team_x  prediction_y       round_y  \
# 36         Liverpool      NaN     Bournemouth             1  Matchweek 21
# 54   Nott'ham Forest      NaN       Brentford             1  Matchweek 21
# 126          Arsenal      NaN  Crystal Palace             1  Matchweek 21
# 288         Brighton      NaN          Wolves             1  Matchweek 21
#
#                        team_y      opponent_y result_y         new_team_y
# 36                  Liverpool     Bournemouth      NaN          Liverpool
# 54          Nottingham Forest       Brentford      NaN  Nottingham Forest
# 126                   Arsenal  Crystal Palace      NaN            Arsenal
# 288  Brighton and Hove Albion          Wolves      NaN           Brighton
